# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import os
import datetime
import pandas as pd
import shutil

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import Sequence
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
import tensorflow as tf
import tensorflow.keras.backend as K


from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

#from Unet_Resnet_Vgg16_Densenet__v22 import build_double_iaunet, focal_dice_boundary_loss

# %%
mol='_densenet_v5T4'

# Parameters
PATCH_SIZE = 256
NUM_CHANNELS = 3
NUM_CLASSES = 1
BATCH_SIZE = 16

dt_tm=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

sys_info=dt_tm
dt_tm = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
file_Sig = mol + dt_tm

# Update paths for Kaggle
patches_dir = "/content/gdrive/MyDrive/ITMO/01_BRIGHT_FIELD/857x21"

out_path= '/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_Output_Files/'+file_Sig+'/'
tensor_path='/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_TensorBoard/'+file_Sig+'/'
tensor_log_path='/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_TensorBoard/'+file_Sig+'/log/'
keras_path='/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_Keras/'+file_Sig+"/"

keras_file=keras_path+file_Sig+'.keras'

os.makedirs(os.path.join(out_path, 'images'), exist_ok=True)
os.makedirs(keras_path, exist_ok=True)
os.makedirs(tensor_log_path, exist_ok=True)

print(f"File Signature:{file_Sig} indicates file/folder name")
# Out:
# File Signature:_densenet_v5T42025-08-20 15:28:26 indicates file/folder name

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.layers import Add, Conv2D

try:
    from tensorflow_addons.layers import InstanceNormalization
    instance_norm_available = True
except ImportError:
    InstanceNormalization = None
    instance_norm_available = False

class InstanceActivation(tf.keras.layers.Layer):
    def __init__(self, name_prefix='ia', debug=False, **kwargs):
        super().__init__(name=name_prefix, **kwargs)
        self.name_prefix = name_prefix
        self.debug = debug

    def build(self, input_shape):
        self.filters = input_shape[-1]
        self.conv = Conv2D(self.filters, (1, 1), activation='relu', padding='same', name=f'{self.name_prefix}_conv')
        self.bn = BatchNormalization(name=f'{self.name_prefix}_bn')

    def call(self, x):
        out = self.conv(x)
        out = self.bn(out)
        if self.debug:
            tf.print(f"[DEBUG] {self.name_prefix}: input shape =", tf.shape(x), ", out shape =", tf.shape(out))
        return Add(name=f'{self.name_prefix}_add')([x, out])

def attention_gate(x, g, inter_channels, name_prefix):
    theta_x = layers.Conv2D(inter_channels, (1, 1), name=f'{name_prefix}_theta_x')(x)
    phi_g = layers.Conv2D(inter_channels, (1, 1), name=f'{name_prefix}_phi_g')(g)
    add = layers.Add(name=f'{name_prefix}_add')([theta_x, phi_g])
    act = layers.Activation('relu', name=f'{name_prefix}_relu')(add)
    psi = layers.Conv2D(1, (1, 1), name=f'{name_prefix}_psi')(act)
    psi = layers.Activation('sigmoid', name=f'{name_prefix}_sigmoid')(psi)
    return layers.Multiply(name=f'{name_prefix}_multiply')([x, psi])

def upsample(filters, size):
    return tf.keras.Sequential([
        layers.Conv2DTranspose(filters, size, strides=2, padding='same'),
        layers.ReLU(),
        BatchNormalization()
    ])

def decoder_conv_block(x, filters, name_prefix):
    x = Conv2D(filters, (3, 3), padding='same', name=f'{name_prefix}_conv1')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn1')(x)
    x = layers.ReLU(name=f'{name_prefix}_relu1')(x)
    x = Conv2D(filters, (3, 3), padding='same', name=f'{name_prefix}_conv2')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn2')(x)
    x = layers.ReLU(name=f'{name_prefix}_relu2')(x)
    return x

def norm_layer(use_instance_norm):
    if use_instance_norm and instance_norm_available:
        return InstanceNormalization()
    return BatchNormalization()

def Unet_Resnet_Vgg16(
    backbone='resnet50',
    input_shape=(256, 256, 3),
    num_classes=1,
    use_attention=False,
    use_instance_norm=False,
    use_ia=False,
    use_mixed_precision=False
):
    if use_mixed_precision:
        from tensorflow.keras import mixed_precision
        mixed_precision.set_global_policy('mixed_float16')

    if backbone == 'resnet50':
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
        layer_names = ['conv1_relu', 'conv2_block3_out', 'conv3_block4_out', 'conv4_block6_out', 'conv5_block3_out']
        backbone_filters = [64, 256, 512, 1024, 2048]
    elif backbone == 'vgg16':
        base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
        layer_names = ['block1_pool', 'block2_pool', 'block3_pool', 'block4_pool', 'block5_pool']
        backbone_filters = [64, 128, 256, 512, 512]
    else:
        raise ValueError("Supported backbones: 'resnet50', 'vgg16'")

    for layer in base_model.layers:
        layer.trainable = False

    inputs = base_model.input
    e1 = base_model.get_layer(layer_names[0]).output
    e2 = base_model.get_layer(layer_names[1]).output
    e3 = base_model.get_layer(layer_names[2]).output
    e4 = base_model.get_layer(layer_names[3]).output
    e5 = base_model.get_layer(layer_names[4]).output

    # Decoder Block 1
    d1 = upsample(backbone_filters[-2], 3)(e5)
    if use_attention:
        e4 = attention_gate(e4, d1, backbone_filters[-2] // 2, name_prefix='attn1')
    d1 = layers.Concatenate()([d1, e4])
    d1 = decoder_conv_block(d1, backbone_filters[-2], name_prefix='dec1')
    if use_ia:
        d1 = InstanceActivation(name_prefix='ia1')(d1)
    d1 = Dropout(0.2)(d1)

    # Decoder Block 2
    d2 = upsample(backbone_filters[-3], 3)(d1)
    if use_attention:
        e3 = attention_gate(e3, d2, backbone_filters[-3] // 2, name_prefix='attn2')
    d2 = layers.Concatenate()([d2, e3])
    d2 = decoder_conv_block(d2, backbone_filters[-3], name_prefix='dec2')
    if use_ia:
        d2 = InstanceActivation(name_prefix='ia2')(d2)
    d2 = Dropout(0.3)(d2)

    # Decoder Block 3
    d3 = upsample(backbone_filters[-4], 3)(d2)
    if use_attention:
        e2 = attention_gate(e2, d3, backbone_filters[-4] // 2, name_prefix='attn3')
    d3 = layers.Concatenate()([d3, e2])
    d3 = decoder_conv_block(d3, backbone_filters[-4], name_prefix='dec3')
    if use_ia:
        d3 = InstanceActivation(name_prefix='ia3')(d3)
    d3 = Dropout(0.35)(d3)

    # Decoder Block 4
    d4 = upsample(backbone_filters[-5], 3)(d3)
    if use_attention:
        e1 = attention_gate(e1, d4, backbone_filters[-5] // 2, name_prefix='attn4')
    d4 = layers.Concatenate()([d4, e1])
    d4 = decoder_conv_block(d4, backbone_filters[-5], name_prefix='dec4')
    if use_ia:
        d4 = InstanceActivation(name_prefix='ia4')(d4)
    d4 = Dropout(0.4)(d4)

    d5 = upsample(backbone_filters[0], 3)(d4)
    d5 = decoder_conv_block(d5, backbone_filters[0], name_prefix='dec5')

    outputs = layers.Conv2D(
        num_classes,
        kernel_size=1,
        activation='sigmoid',
        kernel_regularizer=regularizers.L2(1e-4),
        dtype='float32' if use_mixed_precision else None
    )(d5)

    model = Model(inputs, outputs)
    return model


#  Example usage:
model = Unet_Resnet_Vgg16(
    backbone='vgg16',
    use_attention=True,
    use_ia=False,
    use_instance_norm=False,
    use_mixed_precision=True
)



# Example usage:
model = Unet_Resnet_Vgg16(backbone='vgg16', use_attention=True, use_ia=True)
print("Total params:", model.count_params())
print("Trainable params:", sum(tf.keras.backend.count_params(p) for p in model.trainable_weights))

# Debug print for attention and IA layers
print("\nAttention layers params:")
for layer in model.layers:
    if 'attn' in layer.name:
        print(f"{layer.name}: {layer.count_params()} params")

print("\nInstance Activation layers params:")
for layer in model.layers:
    if 'ia' in layer.name:
        print(f"{layer.name}: {layer.count_params()} params")
# Out:
# I0000 00:00:1754099630.093919      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1754099630.094671      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Total params: 28851173
# Trainable params: 14128421
#
# Attention layers params:
# attn1_theta_x: 131328 params
# attn1_phi_g: 131328 params
# attn1_add: 0 params
# attn1_relu: 0 params
# attn1_psi: 257 params
# attn1_sigmoid: 0 params
# attn1_multiply: 0 params
# attn2_theta_x: 32896 params
# attn2_phi_g: 32896 params
# attn2_add: 0 params
# attn2_relu: 0 params
# attn2_psi: 129 params
# attn2_sigmoid: 0 params
# attn2_multiply: 0 params
# attn3_theta_x: 8256 params
# attn3_phi_g: 8256 params
# attn3_add: 0 params
# attn3_relu: 0 params
# attn3_psi: 65 params
# attn3_sigmoid: 0 params
# attn3_multiply: 0 params
# attn4_theta_x: 2080 params
# attn4_phi_g: 2080 params
# attn4_add: 0 params
# attn4_relu: 0 params
# attn4_psi: 33 params
# attn4_sigmoid: 0 params
# attn4_multiply: 0 params
#
# Instance Activation layers params:
# sequential_5: 2361856 params
# ia1: 264704 params
# sequential_6: 1180928 params
# ia2: 66816 params
# sequential_7: 295552 params
# ia3: 17024 params
# sequential_8: 74048 params
# ia4: 4416 params
# sequential_9: 37184 params

# %%
class PatchDataGenerator(Sequence):
    def __init__(self, patches_dir, indices=None, batch_size=BATCH_SIZE, img_size=PATCH_SIZE, **kwargs):  # ✅ Include **kwargs here
        super().__init__(**kwargs)  # ✅ Now this works
        self.batch_size = batch_size
        self.img_size = img_size
        self.image_files = sorted([os.path.join(patches_dir, 'images', fname) for fname in os.listdir(os.path.join(patches_dir, 'images'))])
        self.mask_files = sorted([os.path.join(patches_dir, 'masks', fname) for fname in os.listdir(os.path.join(patches_dir, 'masks'))])
        if indices is not None:
            self.image_files = [self.image_files[i] for i in indices]
            self.mask_files = [self.mask_files[i] for i in indices]
        self.indices = np.arange(len(self.image_files))

    def __len__(self):
        return len(self.image_files) // self.batch_size

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = np.array([np.load(self.image_files[i]) for i in batch_indices])
        Y_batch = np.array([np.load(self.mask_files[i]) for i in batch_indices])
        return X_batch, Y_batch

# %%
# Metrics and Loss

def jaccard_score(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    y_pred = K.round(y_pred)  # Convert probabilities to binary predictions (0 or 1)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + K.epsilon()) / (union + K.epsilon())  # Add epsilon to avoid division by zero


def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def dice_loss(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    return 1 - (2. * intersection + K.epsilon()) / (K.sum(y_true) + K.sum(y_pred) + K.epsilon())

def dice_bce_loss(y_true, y_pred, bce_weight=0.5, smooth=1e-6):
    # Dice Loss
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    # Weighted BCE (no manual weight needed if using class weights)
    bce_loss = K.binary_crossentropy(y_true, y_pred)

    # Combined Loss
    return bce_weight * bce_loss + (1 - bce_weight) * dice_loss
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred) - (1 - y_true) * K.log(1 - y_pred)
        weight = alpha * K.pow(1 - y_pred, gamma) * y_true + (1 - alpha) * K.pow(y_pred, gamma) * (1 - y_true)
        loss = weight * cross_entropy
        return K.mean(loss)
    return focal_loss_fixed

def boundary_loss(y_true, y_pred):
    # Approximate boundary loss using Laplacian filter on y_pred and y_true
    def laplacian_kernel():
        return tf.constant([[0., 1., 0.],
                            [1., -4., 1.],
                            [0., 1., 0.]], shape=(3, 3, 1, 1), dtype=tf.float32)

    kernel = laplacian_kernel()
    y_true_edge = tf.nn.conv2d(y_true, kernel, strides=1, padding='SAME')
    y_pred_edge = tf.nn.conv2d(y_pred, kernel, strides=1, padding='SAME')
    diff = tf.abs(y_true_edge - y_pred_edge)
    return K.mean(diff)

def focal_dice_boundary_loss(y_true, y_pred, alpha=0.25, gamma=2.0, bce_weight=0.3, boundary_weight=0.1):
    fl = focal_loss(gamma=gamma, alpha=alpha)(y_true, y_pred)
    dl = dice_loss(y_true, y_pred)
    bl = boundary_loss(y_true, y_pred)
    return bce_weight * fl + (1 - bce_weight - boundary_weight) * dl + boundary_weight * bl

# %%
model = Unet_Resnet_Vgg16(
    backbone='vgg16',
    use_attention=True,
    use_instance_norm=False,
    use_mixed_precision=True,
    use_ia=False
)



from tensorflow.keras.optimizers.schedules import ExponentialDecay
lr_schedule1 = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=10000,
    decay_rate=0.9
)


model.compile(
    optimizer=Adam(learning_rate=lr_schedule1),
    loss= focal_dice_boundary_loss, #binary_crossentropy,
    metrics=[
        tf.keras.metrics.TruePositives(name="TP"),
        tf.keras.metrics.FalsePositives(name="FP"),
        tf.keras.metrics.TrueNegatives(name="TN"),
        tf.keras.metrics.FalseNegatives(name="FN"),
        'accuracy',
        recall_m,
        precision_m,
        f1_m,
        jaccard_score
    ]
)
model.summary()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_3 (Cast)       │ (None, 256, 256,  │          0 │ input_layer_12[0… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 256, 256,  │      1,792 │ cast_3[0][0]      │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 256, 256,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 128, 128,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 128, 128,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 128, 128,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 64, 64,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 64, 64,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 64, 64,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 64, 64,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 32, 32,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 32, 32,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 32, 32,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 32, 32,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 16, 16,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 16, 16,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 16, 16,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 16, 16,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 8, 8, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_10       │ (None, 16, 16,    │  2,361,856 │ block5_pool[0][0] │
# │ (Sequential)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_theta_x       │ (None, 16, 16,    │    131,328 │ block4_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_phi_g         │ (None, 16, 16,    │    131,328 │ sequential_10[0]… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_add (Add)     │ (None, 16, 16,    │          0 │ attn1_theta_x[0]… │
# │                     │ 256)              │            │ attn1_phi_g[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_relu          │ (None, 16, 16,    │          0 │ attn1_add[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_psi (Conv2D)  │ (None, 16, 16, 1) │        257 │ attn1_relu[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_sigmoid       │ (None, 16, 16, 1) │          0 │ attn1_psi[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn1_multiply      │ (None, 16, 16,    │          0 │ block4_pool[0][0… │
# │ (Multiply)          │ 512)              │            │ attn1_sigmoid[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 16, 16,    │          0 │ sequential_10[0]… │
# │ (Concatenate)       │ 1024)             │            │ attn1_multiply[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_conv1 (Conv2D) │ (None, 16, 16,    │  4,719,104 │ concatenate_8[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn1            │ (None, 16, 16,    │      2,048 │ dec1_conv1[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_relu1 (ReLU)   │ (None, 16, 16,    │          0 │ dec1_bn1[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_conv2 (Conv2D) │ (None, 16, 16,    │  2,359,808 │ dec1_relu1[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn2            │ (None, 16, 16,    │      2,048 │ dec1_conv2[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_relu2 (ReLU)   │ (None, 16, 16,    │          0 │ dec1_bn2[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 16, 16,    │          0 │ dec1_relu2[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_11       │ (None, 32, 32,    │  1,180,928 │ dropout_8[0][0]   │
# │ (Sequential)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_theta_x       │ (None, 32, 32,    │     32,896 │ block3_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_phi_g         │ (None, 32, 32,    │     32,896 │ sequential_11[0]… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_add (Add)     │ (None, 32, 32,    │          0 │ attn2_theta_x[0]… │
# │                     │ 128)              │            │ attn2_phi_g[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_relu          │ (None, 32, 32,    │          0 │ attn2_add[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_psi (Conv2D)  │ (None, 32, 32, 1) │        129 │ attn2_relu[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_sigmoid       │ (None, 32, 32, 1) │          0 │ attn2_psi[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn2_multiply      │ (None, 32, 32,    │          0 │ block3_pool[0][0… │
# │ (Multiply)          │ 256)              │            │ attn2_sigmoid[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 32, 32,    │          0 │ sequential_11[0]… │
# │ (Concatenate)       │ 512)              │            │ attn2_multiply[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_conv1 (Conv2D) │ (None, 32, 32,    │  1,179,904 │ concatenate_9[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn1            │ (None, 32, 32,    │      1,024 │ dec2_conv1[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_relu1 (ReLU)   │ (None, 32, 32,    │          0 │ dec2_bn1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_conv2 (Conv2D) │ (None, 32, 32,    │    590,080 │ dec2_relu1[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn2            │ (None, 32, 32,    │      1,024 │ dec2_conv2[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_relu2 (ReLU)   │ (None, 32, 32,    │          0 │ dec2_bn2[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32, 32,    │          0 │ dec2_relu2[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_12       │ (None, 64, 64,    │    295,552 │ dropout_9[0][0]   │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_theta_x       │ (None, 64, 64,    │      8,256 │ block2_pool[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_phi_g         │ (None, 64, 64,    │      8,256 │ sequential_12[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_add (Add)     │ (None, 64, 64,    │          0 │ attn3_theta_x[0]… │
# │                     │ 64)               │            │ attn3_phi_g[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_relu          │ (None, 64, 64,    │          0 │ attn3_add[0][0]   │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_psi (Conv2D)  │ (None, 64, 64, 1) │         65 │ attn3_relu[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_sigmoid       │ (None, 64, 64, 1) │          0 │ attn3_psi[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn3_multiply      │ (None, 64, 64,    │          0 │ block2_pool[0][0… │
# │ (Multiply)          │ 128)              │            │ attn3_sigmoid[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 64,    │          0 │ sequential_12[0]… │
# │ (Concatenate)       │ 256)              │            │ attn3_multiply[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_conv1 (Conv2D) │ (None, 64, 64,    │    295,040 │ concatenate_10[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn1            │ (None, 64, 64,    │        512 │ dec3_conv1[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_relu1 (ReLU)   │ (None, 64, 64,    │          0 │ dec3_bn1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_conv2 (Conv2D) │ (None, 64, 64,    │    147,584 │ dec3_relu1[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn2            │ (None, 64, 64,    │        512 │ dec3_conv2[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_relu2 (ReLU)   │ (None, 64, 64,    │          0 │ dec3_bn2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64, 64,    │          0 │ dec3_relu2[0][0]  │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_13       │ (None, 128, 128,  │     74,048 │ dropout_10[0][0]  │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_theta_x       │ (None, 128, 128,  │      2,080 │ block1_pool[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_phi_g         │ (None, 128, 128,  │      2,080 │ sequential_13[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_add (Add)     │ (None, 128, 128,  │          0 │ attn4_theta_x[0]… │
# │                     │ 32)               │            │ attn4_phi_g[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_relu          │ (None, 128, 128,  │          0 │ attn4_add[0][0]   │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_psi (Conv2D)  │ (None, 128, 128,  │         33 │ attn4_relu[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_sigmoid       │ (None, 128, 128,  │          0 │ attn4_psi[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn4_multiply      │ (None, 128, 128,  │          0 │ block1_pool[0][0… │
# │ (Multiply)          │ 64)               │            │ attn4_sigmoid[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ sequential_13[0]… │
# │ (Concatenate)       │ 128)              │            │ attn4_multiply[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_conv1 (Conv2D) │ (None, 128, 128,  │     73,792 │ concatenate_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn1            │ (None, 128, 128,  │        256 │ dec4_conv1[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_relu1 (ReLU)   │ (None, 128, 128,  │          0 │ dec4_bn1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_conv2 (Conv2D) │ (None, 128, 128,  │     36,928 │ dec4_relu1[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn2            │ (None, 128, 128,  │        256 │ dec4_conv2[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_relu2 (ReLU)   │ (None, 128, 128,  │          0 │ dec4_bn2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 128, 128,  │          0 │ dec4_relu2[0][0]  │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_14       │ (None, 256, 256,  │     37,184 │ dropout_11[0][0]  │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_conv1 (Conv2D) │ (None, 256, 256,  │     36,928 │ sequential_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_bn1            │ (None, 256, 256,  │        256 │ dec5_conv1[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_relu1 (ReLU)   │ (None, 256, 256,  │          0 │ dec5_bn1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_conv2 (Conv2D) │ (None, 256, 256,  │     36,928 │ dec5_relu1[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_bn2            │ (None, 256, 256,  │        256 │ dec5_conv2[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_relu2 (ReLU)   │ (None, 256, 256,  │          0 │ dec5_bn2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_4 (Cast)       │ (None, 256, 256,  │          0 │ dec5_relu2[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │         65 │ cast_4[0][0]      │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 28,498,213 (108.71 MB)
#  Trainable params: 13,777,381 (52.56 MB)
#  Non-trainable params: 14,720,832 (56.16 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
import os

# Known prefixes
PREFIXES = ["C_", "S_", "H_", "g_", ""]  # "" handles plain img_/mask_

# Helper: extract prefix, key, and type (image/mask)
def extract_key_and_prefix(fname, img_or_mask):
    for prefix in PREFIXES:
        img_prefix = f"{prefix}img_" if prefix else "img_"
        mask_prefix = f"{prefix}mask_" if prefix else "mask_"

        if img_or_mask == "img" and fname.startswith(img_prefix):
            return fname.replace(img_prefix, ""), prefix if prefix else "plain"
        elif img_or_mask == "mask" and fname.startswith(mask_prefix):
            return fname.replace(mask_prefix, ""), prefix if prefix else "plain"
    return None, None  # Unrecognized

# Directories
image_dir = os.path.join(patches_dir, 'images')
mask_dir = os.path.join(patches_dir, 'masks')

# Build image dictionary
image_dict = {}
for fname in os.listdir(image_dir):
    if not fname.endswith(".npy"):
        continue
    key, prefix = extract_key_and_prefix(fname, "img")
    if key:
        image_dict[(key, prefix)] = os.path.join(image_dir, fname)

# Build mask dictionary
mask_dict = {}
for fname in os.listdir(mask_dir):
    if not fname.endswith(".npy"):
        continue
    key, prefix = extract_key_and_prefix(fname, "mask")
    if key:
        mask_dict[(key, prefix)] = os.path.join(mask_dir, fname)

# Get matching image-mask pairs
matching_keys = sorted(set(image_dict.keys()) & set(mask_dict.keys()))

# Final aligned file lists
image_files = [image_dict[k] for k in matching_keys]
mask_files = [mask_dict[k] for k in matching_keys]

# %%
# Data Split
train_indices, val_indices = train_test_split(np.arange(len(image_files)), test_size=0.2, random_state=42)

train_gen = PatchDataGenerator(patches_dir, indices=train_indices, batch_size=BATCH_SIZE)
val_gen = PatchDataGenerator(patches_dir, indices=val_indices, batch_size=BATCH_SIZE)

# %%
# Callbacks
log_dir = os.path.join(tensor_log_path, "fit_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True, update_freq='epoch' )
#checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(keras_path, save_best_only=True)
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=keras_path+file_Sig+"_1st_{epoch:02d}.keras",  # dynamic naming
    save_freq='epoch',
    save_weights_only=False,  # Save the full model (not just weights)
    save_best_only=False,     # Save all epochs (not just the best one)
    verbose=1
)

csv_logger = tf.keras.callbacks.CSVLogger(training_log.csv), append=True)

# %%
# Train with more epochs
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=45,
    callbacks=[csv_logger, tensorboard_callback, checkpoint_callback, early_stopping],
    verbose=1,
    #workers=45,
    #use_multiprocessing=True,
    #max_queue_size=10
)
# Out:
# Epoch 1/45
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754052622.739993      95 service.cc:148] XLA service 0x7ea9500039e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754052622.741159      95 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754052622.741179      95 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754052625.373793      95 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-08-01 12:50:48.094542: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[16,256,256,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:50:53.079716: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 5.985281553s
# Trying algorithm eng0{} for conv (f16[16,256,256,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[64,3,3,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:06.619583: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[256,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,512]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:06.620614: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.001147948s
# Trying algorithm eng19{k2=0} for conv (f16[256,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,512]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:09.749300: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,256]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:10.972733: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.223548244s
# Trying algorithm eng19{k2=2} for conv (f16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,256]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:11.972942: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,256]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:12.693313: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.720475228s
# Trying algorithm eng19{k2=3} for conv (f16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,256]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:13.693506: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,256]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:15.587550: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.894134415s
# Trying algorithm eng19{k2=0} for conv (f16[128,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,256]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:18.547778: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,128]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:18.821652: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.273972965s
# Trying algorithm eng19{k2=0} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,128]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:20.019980: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[128,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,129,129,64]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:20.502960: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.48315881s
# Trying algorithm eng19{k2=0} for conv (f16[128,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,129,129,64]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:22.621172: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[64,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,128]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:25.006169: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.385096139s
# Trying algorithm eng19{k2=3} for conv (f16[64,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,128]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:26.006389: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[64,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,128]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:28.830813: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.824527356s
# Trying algorithm eng19{k2=0} for conv (f16[64,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,128]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:29.831035: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[64,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,128]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:31.959748: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.128818556s
# Trying algorithm eng19{k2=2} for conv (f16[64,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,128]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:33.355726: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:33.807602: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.451973112s
# Trying algorithm eng19{k2=3} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:34.807801: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:35.544990: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.737287032s
# Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:36.545194: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:36.958416: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.413321771s
# Trying algorithm eng19{k2=2} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:38.537253: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,257,257,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:41.280578: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.743505965s
# Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,257,257,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:44.695908: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:52.421724: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 8.725938799s
# Trying algorithm eng19{k2=3} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:53.421939: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:51:59.039442: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.617607508s
# Trying algorithm eng19{k2=2} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:52:00.039653: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:52:07.279985: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 8.240436541s
# Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:52:08.280203: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-01 12:53:03.187654: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 55.907558912s
# Trying algorithm eng0{} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,64]{3,2,1,0}, f16[16,256,256,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1754052794.920061      95 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - FN: 26600904.0000 - FP: 47943552.0000 - TN: 322202080.0000 - TP: 75112624.0000 - accuracy: 0.8239 - f1_m: 0.6385 - jaccard_score: 0.4784 - loss: 0.3059 - precision_m: 0.5820 - recall_m: 0.7264
# Epoch 1: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_01.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 708s 571ms/step - FN: 26629072.0000 - FP: 47982060.0000 - TN: 322574880.0000 - TP: 75196272.0000 - accuracy: 0.8240 - f1_m: 0.6385 - jaccard_score: 0.4785 - loss: 0.3058 - precision_m: 0.5821 - recall_m: 0.7264 - val_FN: 18170396.0000 - val_FP: 6841729.0000 - val_TN: 180200992.0000 - val_TP: 30716550.0000 - val_accuracy: 0.8940 - val_f1_m: 0.7035 - val_jaccard_score: 0.5468 - val_loss: 0.2307 - val_precision_m: 0.8159 - val_recall_m: 0.6236
# Epoch 2/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 23873320.0000 - FP: 28061994.0000 - TN: 342896256.0000 - TP: 77027608.0000 - accuracy: 0.8891 - f1_m: 0.7440 - jaccard_score: 0.5947 - loss: 0.2133 - precision_m: 0.7280 - recall_m: 0.7673
# Epoch 2: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_02.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 23899248.0000 - FP: 28091828.0000 - TN: 343276800.0000 - TP: 77114400.0000 - accuracy: 0.8891 - f1_m: 0.7440 - jaccard_score: 0.5947 - loss: 0.2133 - precision_m: 0.7280 - recall_m: 0.7673 - val_FN: 13140079.0000 - val_FP: 8910188.0000 - val_TN: 178132400.0000 - val_TP: 35746860.0000 - val_accuracy: 0.9065 - val_f1_m: 0.7596 - val_jaccard_score: 0.6154 - val_loss: 0.1947 - val_precision_m: 0.7989 - val_recall_m: 0.7275
# Epoch 3/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 21597402.0000 - FP: 23946946.0000 - TN: 346689248.0000 - TP: 79625640.0000 - accuracy: 0.9031 - f1_m: 0.7736 - jaccard_score: 0.6329 - loss: 0.1894 - precision_m: 0.7639 - recall_m: 0.7878
# Epoch 3: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_03.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 21620992.0000 - FP: 23972762.0000 - TN: 347074208.0000 - TP: 79714416.0000 - accuracy: 0.9031 - f1_m: 0.7736 - jaccard_score: 0.6329 - loss: 0.1894 - precision_m: 0.7639 - recall_m: 0.7878 - val_FN: 14441355.0000 - val_FP: 5924799.0000 - val_TN: 181117824.0000 - val_TP: 34445572.0000 - val_accuracy: 0.9137 - val_f1_m: 0.7670 - val_jaccard_score: 0.6252 - val_loss: 0.1862 - val_precision_m: 0.8522 - val_recall_m: 0.7004
# Epoch 4/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 19825764.0000 - FP: 20614744.0000 - TN: 350138624.0000 - TP: 81279920.0000 - accuracy: 0.9136 - f1_m: 0.7969 - jaccard_score: 0.6645 - loss: 0.1714 - precision_m: 0.7933 - recall_m: 0.8039
# Epoch 4: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_04.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 172s 192ms/step - FN: 19847436.0000 - FP: 20637180.0000 - TN: 350526816.0000 - TP: 81370744.0000 - accuracy: 0.9136 - f1_m: 0.7969 - jaccard_score: 0.6645 - loss: 0.1714 - precision_m: 0.7933 - recall_m: 0.8039 - val_FN: 12277599.0000 - val_FP: 7112409.0000 - val_TN: 179930256.0000 - val_TP: 36609328.0000 - val_accuracy: 0.9178 - val_f1_m: 0.7873 - val_jaccard_score: 0.6517 - val_loss: 0.1740 - val_precision_m: 0.8361 - val_recall_m: 0.7463
# Epoch 5/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 18148924.0000 - FP: 18450574.0000 - TN: 351961344.0000 - TP: 83298360.0000 - accuracy: 0.9222 - f1_m: 0.8182 - jaccard_score: 0.6943 - loss: 0.1555 - precision_m: 0.8150 - recall_m: 0.8239
# Epoch 5: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_05.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 18169228.0000 - FP: 18470898.0000 - TN: 352352032.0000 - TP: 83390168.0000 - accuracy: 0.9222 - f1_m: 0.8182 - jaccard_score: 0.6943 - loss: 0.1555 - precision_m: 0.8150 - recall_m: 0.8239 - val_FN: 10190260.0000 - val_FP: 7596250.0000 - val_TN: 179446352.0000 - val_TP: 38696672.0000 - val_accuracy: 0.9246 - val_f1_m: 0.8102 - val_jaccard_score: 0.6831 - val_loss: 0.1573 - val_precision_m: 0.8344 - val_recall_m: 0.7889
# Epoch 6/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 17230134.0000 - FP: 16883884.0000 - TN: 353191392.0000 - TP: 84553880.0000 - accuracy: 0.9276 - f1_m: 0.8309 - jaccard_score: 0.7124 - loss: 0.1456 - precision_m: 0.8317 - recall_m: 0.8320
# Epoch 6: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_06.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 17248712.0000 - FP: 16902224.0000 - TN: 353584448.0000 - TP: 84647040.0000 - accuracy: 0.9276 - f1_m: 0.8309 - jaccard_score: 0.7124 - loss: 0.1456 - precision_m: 0.8317 - recall_m: 0.8320 - val_FN: 10668734.0000 - val_FP: 6523598.0000 - val_TN: 180519072.0000 - val_TP: 38218200.0000 - val_accuracy: 0.9271 - val_f1_m: 0.8134 - val_jaccard_score: 0.6878 - val_loss: 0.1547 - val_precision_m: 0.8528 - val_recall_m: 0.7795
# Epoch 7/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 15997022.0000 - FP: 15422815.0000 - TN: 355251072.0000 - TP: 85188384.0000 - accuracy: 0.9340 - f1_m: 0.8432 - jaccard_score: 0.7304 - loss: 0.1357 - precision_m: 0.8452 - recall_m: 0.8431
# Epoch 7: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_07.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 16014797.0000 - FP: 15440034.0000 - TN: 355644576.0000 - TP: 85283016.0000 - accuracy: 0.9340 - f1_m: 0.8432 - jaccard_score: 0.7304 - loss: 0.1357 - precision_m: 0.8452 - recall_m: 0.8431 - val_FN: 11225943.0000 - val_FP: 5384260.0000 - val_TN: 181658416.0000 - val_TP: 37660984.0000 - val_accuracy: 0.9296 - val_f1_m: 0.8159 - val_jaccard_score: 0.6916 - val_loss: 0.1516 - val_precision_m: 0.8739 - val_recall_m: 0.7675
# Epoch 8/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 14968269.0000 - FP: 14409825.0000 - TN: 356191360.0000 - TP: 86289728.0000 - accuracy: 0.9376 - f1_m: 0.8534 - jaccard_score: 0.7457 - loss: 0.1281 - precision_m: 0.8554 - recall_m: 0.8530
# Epoch 8: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_08.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 172s 192ms/step - FN: 14985193.0000 - FP: 14425823.0000 - TN: 356586176.0000 - TP: 86385128.0000 - accuracy: 0.9376 - f1_m: 0.8534 - jaccard_score: 0.7457 - loss: 0.1281 - precision_m: 0.8554 - recall_m: 0.8530 - val_FN: 11652966.0000 - val_FP: 4779476.0000 - val_TN: 182263216.0000 - val_TP: 37233968.0000 - val_accuracy: 0.9304 - val_f1_m: 0.8161 - val_jaccard_score: 0.6919 - val_loss: 0.1520 - val_precision_m: 0.8848 - val_recall_m: 0.7598
# Epoch 9/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 14435335.0000 - FP: 13498747.0000 - TN: 356713280.0000 - TP: 87211864.0000 - accuracy: 0.9409 - f1_m: 0.8608 - jaccard_score: 0.7569 - loss: 0.1224 - precision_m: 0.8644 - recall_m: 0.8584
# Epoch 9: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_09.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 14451306.0000 - FP: 13513873.0000 - TN: 357109408.0000 - TP: 87307784.0000 - accuracy: 0.9409 - f1_m: 0.8608 - jaccard_score: 0.7568 - loss: 0.1224 - precision_m: 0.8644 - recall_m: 0.8584 - val_FN: 10823063.0000 - val_FP: 5072054.0000 - val_TN: 181970608.0000 - val_TP: 38063884.0000 - val_accuracy: 0.9326 - val_f1_m: 0.8237 - val_jaccard_score: 0.7027 - val_loss: 0.1448 - val_precision_m: 0.8811 - val_recall_m: 0.7755
# Epoch 10/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 13495047.0000 - FP: 12756121.0000 - TN: 358493344.0000 - TP: 87114840.0000 - accuracy: 0.9444 - f1_m: 0.8680 - jaccard_score: 0.7680 - loss: 0.1165 - precision_m: 0.8707 - recall_m: 0.8664
# Epoch 10: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_10.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 13510690.0000 - FP: 12770604.0000 - TN: 358888960.0000 - TP: 87212240.0000 - accuracy: 0.9444 - f1_m: 0.8680 - jaccard_score: 0.7680 - loss: 0.1165 - precision_m: 0.8707 - recall_m: 0.8664 - val_FN: 12766108.0000 - val_FP: 3716870.0000 - val_TN: 183325712.0000 - val_TP: 36120832.0000 - val_accuracy: 0.9301 - val_f1_m: 0.8102 - val_jaccard_score: 0.6837 - val_loss: 0.1537 - val_precision_m: 0.9060 - val_recall_m: 0.7354
# Epoch 11/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 13210711.0000 - FP: 12278654.0000 - TN: 357708896.0000 - TP: 88660840.0000 - accuracy: 0.9457 - f1_m: 0.8721 - jaccard_score: 0.7743 - loss: 0.1132 - precision_m: 0.8763 - recall_m: 0.8689
# Epoch 11: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_11.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 13225299.0000 - FP: 12292254.0000 - TN: 358106784.0000 - TP: 88757888.0000 - accuracy: 0.9457 - f1_m: 0.8721 - jaccard_score: 0.7743 - loss: 0.1132 - precision_m: 0.8763 - recall_m: 0.8689 - val_FN: 8818513.0000 - val_FP: 5913484.0000 - val_TN: 181129136.0000 - val_TP: 40068424.0000 - val_accuracy: 0.9376 - val_f1_m: 0.8420 - val_jaccard_score: 0.7293 - val_loss: 0.1337 - val_precision_m: 0.8703 - val_recall_m: 0.8174
# Epoch 12/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 12697356.0000 - FP: 11728284.0000 - TN: 359209696.0000 - TP: 88223792.0000 - accuracy: 0.9485 - f1_m: 0.8775 - jaccard_score: 0.7828 - loss: 0.1089 - precision_m: 0.8816 - recall_m: 0.8744
# Epoch 12: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_12.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 12711609.0000 - FP: 11741368.0000 - TN: 359607040.0000 - TP: 88322232.0000 - accuracy: 0.9485 - f1_m: 0.8775 - jaccard_score: 0.7828 - loss: 0.1089 - precision_m: 0.8816 - recall_m: 0.8744 - val_FN: 10432557.0000 - val_FP: 4554127.0000 - val_TN: 182488512.0000 - val_TP: 38454392.0000 - val_accuracy: 0.9365 - val_f1_m: 0.8339 - val_jaccard_score: 0.7173 - val_loss: 0.1388 - val_precision_m: 0.8933 - val_recall_m: 0.7838
# Epoch 13/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 12062943.0000 - FP: 11317338.0000 - TN: 360264128.0000 - TP: 88214664.0000 - accuracy: 0.9508 - f1_m: 0.8826 - jaccard_score: 0.7908 - loss: 0.1049 - precision_m: 0.8856 - recall_m: 0.8805
# Epoch 13: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_13.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 12076796.0000 - FP: 11330123.0000 - TN: 360661056.0000 - TP: 88314224.0000 - accuracy: 0.9508 - f1_m: 0.8826 - jaccard_score: 0.7908 - loss: 0.1049 - precision_m: 0.8856 - recall_m: 0.8805 - val_FN: 9454929.0000 - val_FP: 4925932.0000 - val_TN: 182116672.0000 - val_TP: 39432040.0000 - val_accuracy: 0.9390 - val_f1_m: 0.8430 - val_jaccard_score: 0.7308 - val_loss: 0.1311 - val_precision_m: 0.8880 - val_recall_m: 0.8041
# Epoch 14/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 11781998.0000 - FP: 10820729.0000 - TN: 359804992.0000 - TP: 89451608.0000 - accuracy: 0.9519 - f1_m: 0.8873 - jaccard_score: 0.7984 - loss: 0.1013 - precision_m: 0.8913 - recall_m: 0.8841
# Epoch 14: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_14.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 11795005.0000 - FP: 10832922.0000 - TN: 360203552.0000 - TP: 89550952.0000 - accuracy: 0.9519 - f1_m: 0.8873 - jaccard_score: 0.7984 - loss: 0.1013 - precision_m: 0.8913 - recall_m: 0.8841 - val_FN: 11044262.0000 - val_FP: 4221991.0000 - val_TN: 182820720.0000 - val_TP: 37842664.0000 - val_accuracy: 0.9353 - val_f1_m: 0.8299 - val_jaccard_score: 0.7113 - val_loss: 0.1403 - val_precision_m: 0.8986 - val_recall_m: 0.7723
# Epoch 15/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 11349931.0000 - FP: 10474946.0000 - TN: 360206304.0000 - TP: 89828064.0000 - accuracy: 0.9540 - f1_m: 0.8917 - jaccard_score: 0.8055 - loss: 0.0978 - precision_m: 0.8953 - recall_m: 0.8888
# Epoch 15: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_15.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 11362747.0000 - FP: 10486747.0000 - TN: 360605216.0000 - TP: 89927656.0000 - accuracy: 0.9540 - f1_m: 0.8917 - jaccard_score: 0.8055 - loss: 0.0978 - precision_m: 0.8953 - recall_m: 0.8888 - val_FN: 11995974.0000 - val_FP: 3242892.0000 - val_TN: 183799840.0000 - val_TP: 36890968.0000 - val_accuracy: 0.9354 - val_f1_m: 0.8251 - val_jaccard_score: 0.7049 - val_loss: 0.1424 - val_precision_m: 0.9187 - val_recall_m: 0.7514
# Epoch 16/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 11341598.0000 - FP: 10357807.0000 - TN: 359917504.0000 - TP: 90242184.0000 - accuracy: 0.9540 - f1_m: 0.8917 - jaccard_score: 0.8054 - loss: 0.0977 - precision_m: 0.8965 - recall_m: 0.8878
# Epoch 16: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_16.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 11353807.0000 - FP: 10369143.0000 - TN: 360317312.0000 - TP: 90341936.0000 - accuracy: 0.9540 - f1_m: 0.8917 - jaccard_score: 0.8054 - loss: 0.0977 - precision_m: 0.8965 - recall_m: 0.8878 - val_FN: 9017821.0000 - val_FP: 4852969.0000 - val_TN: 182189744.0000 - val_TP: 39869124.0000 - val_accuracy: 0.9412 - val_f1_m: 0.8495 - val_jaccard_score: 0.7406 - val_loss: 0.1277 - val_precision_m: 0.8906 - val_recall_m: 0.8138
# Epoch 17/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 10652056.0000 - FP: 9934123.0000 - TN: 360410048.0000 - TP: 90863024.0000 - accuracy: 0.9564 - f1_m: 0.8976 - jaccard_score: 0.8149 - loss: 0.0931 - precision_m: 0.9005 - recall_m: 0.8952
# Epoch 17: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_17.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 10663854.0000 - FP: 9945170.0000 - TN: 360810112.0000 - TP: 90963264.0000 - accuracy: 0.9564 - f1_m: 0.8976 - jaccard_score: 0.8149 - loss: 0.0931 - precision_m: 0.9005 - recall_m: 0.8952 - val_FN: 9943884.0000 - val_FP: 4250711.0000 - val_TN: 182791920.0000 - val_TP: 38943064.0000 - val_accuracy: 0.9398 - val_f1_m: 0.8437 - val_jaccard_score: 0.7316 - val_loss: 0.1308 - val_precision_m: 0.9005 - val_recall_m: 0.7951
# Epoch 18/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 10263446.0000 - FP: 9613601.0000 - TN: 361569920.0000 - TP: 90412496.0000 - accuracy: 0.9577 - f1_m: 0.8999 - jaccard_score: 0.8187 - loss: 0.0912 - precision_m: 0.9027 - recall_m: 0.8976
# Epoch 18: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_18.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 174s 193ms/step - FN: 10274866.0000 - FP: 9624306.0000 - TN: 361969376.0000 - TP: 90514048.0000 - accuracy: 0.9577 - f1_m: 0.8999 - jaccard_score: 0.8187 - loss: 0.0912 - precision_m: 0.9027 - recall_m: 0.8976 - val_FN: 9000150.0000 - val_FP: 4532643.0000 - val_TN: 182510016.0000 - val_TP: 39886800.0000 - val_accuracy: 0.9426 - val_f1_m: 0.8526 - val_jaccard_score: 0.7451 - val_loss: 0.1251 - val_precision_m: 0.8969 - val_recall_m: 0.8140
# Epoch 19/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 9918764.0000 - FP: 9346368.0000 - TN: 360167104.0000 - TP: 92427064.0000 - accuracy: 0.9591 - f1_m: 0.9058 - jaccard_score: 0.8284 - loss: 0.0870 - precision_m: 0.9081 - recall_m: 0.9039
# Epoch 19: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_19.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 174s 193ms/step - FN: 9929781.0000 - FP: 9356701.0000 - TN: 360568768.0000 - TP: 92527160.0000 - accuracy: 0.9591 - f1_m: 0.9058 - jaccard_score: 0.8284 - loss: 0.0870 - precision_m: 0.9081 - recall_m: 0.9039 - val_FN: 8912249.0000 - val_FP: 4560623.0000 - val_TN: 182482000.0000 - val_TP: 39974676.0000 - val_accuracy: 0.9429 - val_f1_m: 0.8536 - val_jaccard_score: 0.7466 - val_loss: 0.1243 - val_precision_m: 0.8964 - val_recall_m: 0.8161
# Epoch 20/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 9606643.0000 - FP: 9135245.0000 - TN: 361152800.0000 - TP: 91964496.0000 - accuracy: 0.9606 - f1_m: 0.9079 - jaccard_score: 0.8319 - loss: 0.0851 - precision_m: 0.9098 - recall_m: 0.9064
# Epoch 20: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_20.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 174s 193ms/step - FN: 9617589.0000 - FP: 9145487.0000 - TN: 361553696.0000 - TP: 92065528.0000 - accuracy: 0.9606 - f1_m: 0.9079 - jaccard_score: 0.8319 - loss: 0.0851 - precision_m: 0.9098 - recall_m: 0.9064 - val_FN: 9302244.0000 - val_FP: 4466729.0000 - val_TN: 182575952.0000 - val_TP: 39584712.0000 - val_accuracy: 0.9416 - val_f1_m: 0.8498 - val_jaccard_score: 0.7408 - val_loss: 0.1272 - val_precision_m: 0.8977 - val_recall_m: 0.8083
# Epoch 21/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9507793.0000 - FP: 9082315.0000 - TN: 362101728.0000 - TP: 91167320.0000 - accuracy: 0.9609 - f1_m: 0.9072 - jaccard_score: 0.8307 - loss: 0.0853 - precision_m: 0.9085 - recall_m: 0.9062
# Epoch 21: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_21.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 9518460.0000 - FP: 9092372.0000 - TN: 362501824.0000 - TP: 91269624.0000 - accuracy: 0.9609 - f1_m: 0.9072 - jaccard_score: 0.8307 - loss: 0.0853 - precision_m: 0.9085 - recall_m: 0.9062 - val_FN: 8334439.0000 - val_FP: 4874985.0000 - val_TN: 182167648.0000 - val_TP: 40552512.0000 - val_accuracy: 0.9440 - val_f1_m: 0.8578 - val_jaccard_score: 0.7530 - val_loss: 0.1214 - val_precision_m: 0.8915 - val_recall_m: 0.8280
# Epoch 22/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9186362.0000 - FP: 8694615.0000 - TN: 362051136.0000 - TP: 91927168.0000 - accuracy: 0.9621 - f1_m: 0.9110 - jaccard_score: 0.8371 - loss: 0.0824 - precision_m: 0.9129 - recall_m: 0.9095
# Epoch 22: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_22.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 9196817.0000 - FP: 8704407.0000 - TN: 362452000.0000 - TP: 92029192.0000 - accuracy: 0.9621 - f1_m: 0.9110 - jaccard_score: 0.8371 - loss: 0.0824 - precision_m: 0.9129 - recall_m: 0.9095 - val_FN: 11020680.0000 - val_FP: 3414461.0000 - val_TN: 183628192.0000 - val_TP: 37866256.0000 - val_accuracy: 0.9388 - val_f1_m: 0.8370 - val_jaccard_score: 0.7222 - val_loss: 0.1363 - val_precision_m: 0.9165 - val_recall_m: 0.7724
# Epoch 23/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8858316.0000 - FP: 8459394.0000 - TN: 362767456.0000 - TP: 91774040.0000 - accuracy: 0.9636 - f1_m: 0.9135 - jaccard_score: 0.8412 - loss: 0.0801 - precision_m: 0.9154 - recall_m: 0.9119
# Epoch 23: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_23.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 172s 192ms/step - FN: 8868624.0000 - FP: 8469121.0000 - TN: 363167840.0000 - TP: 91876752.0000 - accuracy: 0.9636 - f1_m: 0.9135 - jaccard_score: 0.8412 - loss: 0.0801 - precision_m: 0.9154 - recall_m: 0.9119 - val_FN: 8738906.0000 - val_FP: 4455855.0000 - val_TN: 182586848.0000 - val_TP: 40148040.0000 - val_accuracy: 0.9441 - val_f1_m: 0.8565 - val_jaccard_score: 0.7513 - val_loss: 0.1225 - val_precision_m: 0.8996 - val_recall_m: 0.8196
# Epoch 24/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8781331.0000 - FP: 8334849.5000 - TN: 362412192.0000 - TP: 92330912.0000 - accuracy: 0.9636 - f1_m: 0.9147 - jaccard_score: 0.8433 - loss: 0.0793 - precision_m: 0.9170 - recall_m: 0.9127
# Epoch 24: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_24.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 8791125.0000 - FP: 8344209.0000 - TN: 362813472.0000 - TP: 92433600.0000 - accuracy: 0.9636 - f1_m: 0.9147 - jaccard_score: 0.8433 - loss: 0.0793 - precision_m: 0.9170 - recall_m: 0.9127 - val_FN: 8662895.0000 - val_FP: 4346267.0000 - val_TN: 182696416.0000 - val_TP: 40224028.0000 - val_accuracy: 0.9449 - val_f1_m: 0.8584 - val_jaccard_score: 0.7541 - val_loss: 0.1210 - val_precision_m: 0.9017 - val_recall_m: 0.8207
# Epoch 25/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8578215.0000 - FP: 8219566.0000 - TN: 362526688.0000 - TP: 92534792.0000 - accuracy: 0.9644 - f1_m: 0.9165 - jaccard_score: 0.8463 - loss: 0.0780 - precision_m: 0.9179 - recall_m: 0.9153
# Epoch 25: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_25.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 8587814.0000 - FP: 8228745.5000 - TN: 362928160.0000 - TP: 92637680.0000 - accuracy: 0.9644 - f1_m: 0.9165 - jaccard_score: 0.8463 - loss: 0.0780 - precision_m: 0.9179 - recall_m: 0.9153 - val_FN: 7912720.0000 - val_FP: 4795155.0000 - val_TN: 182247456.0000 - val_TP: 40974224.0000 - val_accuracy: 0.9461 - val_f1_m: 0.8636 - val_jaccard_score: 0.7621 - val_loss: 0.1177 - val_precision_m: 0.8939 - val_recall_m: 0.8367
# Epoch 26/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 8377139.5000 - FP: 8051804.0000 - TN: 362985568.0000 - TP: 92444576.0000 - accuracy: 0.9655 - f1_m: 0.9183 - jaccard_score: 0.8494 - loss: 0.0764 - precision_m: 0.9196 - recall_m: 0.9172
# Epoch 26: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_26.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 174s 193ms/step - FN: 8386482.5000 - FP: 8060726.0000 - TN: 363386944.0000 - TP: 92548040.0000 - accuracy: 0.9655 - f1_m: 0.9183 - jaccard_score: 0.8494 - loss: 0.0764 - precision_m: 0.9196 - recall_m: 0.9172 - val_FN: 7302271.0000 - val_FP: 5254547.0000 - val_TN: 181788048.0000 - val_TP: 41584672.0000 - val_accuracy: 0.9468 - val_f1_m: 0.8668 - val_jaccard_score: 0.7670 - val_loss: 0.1162 - val_precision_m: 0.8868 - val_recall_m: 0.8492
# Epoch 27/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 8201930.0000 - FP: 7901779.0000 - TN: 363646784.0000 - TP: 92108744.0000 - accuracy: 0.9658 - f1_m: 0.9194 - jaccard_score: 0.8512 - loss: 0.0756 - precision_m: 0.9204 - recall_m: 0.9185
# Epoch 27: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_27.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 8211254.0000 - FP: 7910684.0000 - TN: 364047616.0000 - TP: 92212792.0000 - accuracy: 0.9658 - f1_m: 0.9194 - jaccard_score: 0.8512 - loss: 0.0756 - precision_m: 0.9204 - recall_m: 0.9185 - val_FN: 8965855.0000 - val_FP: 4083278.0000 - val_TN: 182959296.0000 - val_TP: 39921080.0000 - val_accuracy: 0.9447 - val_f1_m: 0.8571 - val_jaccard_score: 0.7521 - val_loss: 0.1216 - val_precision_m: 0.9063 - val_recall_m: 0.8146
# Epoch 28/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8150308.0000 - FP: 7815844.5000 - TN: 362596896.0000 - TP: 93296240.0000 - accuracy: 0.9660 - f1_m: 0.9208 - jaccard_score: 0.8536 - loss: 0.0746 - precision_m: 0.9223 - recall_m: 0.9194
# Epoch 28: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_28.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 8159284.0000 - FP: 7824516.5000 - TN: 362999232.0000 - TP: 93399376.0000 - accuracy: 0.9660 - f1_m: 0.9208 - jaccard_score: 0.8536 - loss: 0.0746 - precision_m: 0.9223 - recall_m: 0.9194 - val_FN: 7741889.0000 - val_FP: 4702362.0000 - val_TN: 182340352.0000 - val_TP: 41145052.0000 - val_accuracy: 0.9473 - val_f1_m: 0.8666 - val_jaccard_score: 0.7666 - val_loss: 0.1153 - val_precision_m: 0.8963 - val_recall_m: 0.8402
# Epoch 29/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7900892.0000 - FP: 7611404.0000 - TN: 363054912.0000 - TP: 93292064.0000 - accuracy: 0.9671 - f1_m: 0.9228 - jaccard_score: 0.8571 - loss: 0.0728 - precision_m: 0.9243 - recall_m: 0.9216
# Epoch 29: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_29.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 7909754.0000 - FP: 7619933.5000 - TN: 363457120.0000 - TP: 93395600.0000 - accuracy: 0.9671 - f1_m: 0.9228 - jaccard_score: 0.8571 - loss: 0.0728 - precision_m: 0.9243 - recall_m: 0.9216 - val_FN: 8331745.0000 - val_FP: 4253037.0000 - val_TN: 182789584.0000 - val_TP: 40555184.0000 - val_accuracy: 0.9467 - val_f1_m: 0.8635 - val_jaccard_score: 0.7619 - val_loss: 0.1178 - val_precision_m: 0.9041 - val_recall_m: 0.8278
# Epoch 30/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7782963.0000 - FP: 7536403.5000 - TN: 363503360.0000 - TP: 93036424.0000 - accuracy: 0.9674 - f1_m: 0.9233 - jaccard_score: 0.8579 - loss: 0.0724 - precision_m: 0.9240 - recall_m: 0.9227
# Epoch 30: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_30.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 7791578.5000 - FP: 7544744.5000 - TN: 363905344.0000 - TP: 93140616.0000 - accuracy: 0.9674 - f1_m: 0.9233 - jaccard_score: 0.8579 - loss: 0.0724 - precision_m: 0.9240 - recall_m: 0.9227 - val_FN: 7405796.0000 - val_FP: 5058795.0000 - val_TN: 181983872.0000 - val_TP: 41481160.0000 - val_accuracy: 0.9472 - val_f1_m: 0.8676 - val_jaccard_score: 0.7681 - val_loss: 0.1154 - val_precision_m: 0.8903 - val_recall_m: 0.8473
# Epoch 31/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 7657811.5000 - FP: 7414589.0000 - TN: 362878592.0000 - TP: 93908272.0000 - accuracy: 0.9681 - f1_m: 0.9255 - jaccard_score: 0.8615 - loss: 0.0707 - precision_m: 0.9266 - recall_m: 0.9244
# Epoch 31: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_31.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 7666323.5000 - FP: 7422831.5000 - TN: 363281472.0000 - TP: 94011744.0000 - accuracy: 0.9681 - f1_m: 0.9255 - jaccard_score: 0.8615 - loss: 0.0707 - precision_m: 0.9266 - recall_m: 0.9244 - val_FN: 8478021.0000 - val_FP: 4139778.0000 - val_TN: 182902928.0000 - val_TP: 40408928.0000 - val_accuracy: 0.9465 - val_f1_m: 0.8627 - val_jaccard_score: 0.7607 - val_loss: 0.1179 - val_precision_m: 0.9064 - val_recall_m: 0.8247
# Epoch 32/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7447085.0000 - FP: 7231012.5000 - TN: 363435744.0000 - TP: 93745336.0000 - accuracy: 0.9689 - f1_m: 0.9274 - jaccard_score: 0.8650 - loss: 0.0691 - precision_m: 0.9285 - recall_m: 0.9265
# Epoch 32: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_32.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 7455417.0000 - FP: 7239102.0000 - TN: 363838400.0000 - TP: 93849400.0000 - accuracy: 0.9689 - f1_m: 0.9274 - jaccard_score: 0.8650 - loss: 0.0691 - precision_m: 0.9285 - recall_m: 0.9265 - val_FN: 7784756.0000 - val_FP: 4553129.0000 - val_TN: 182489552.0000 - val_TP: 41102184.0000 - val_accuracy: 0.9477 - val_f1_m: 0.8677 - val_jaccard_score: 0.7684 - val_loss: 0.1151 - val_precision_m: 0.8992 - val_recall_m: 0.8396
# Epoch 33/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7339098.5000 - FP: 7126814.0000 - TN: 363281536.0000 - TP: 94111568.0000 - accuracy: 0.9694 - f1_m: 0.9282 - jaccard_score: 0.8664 - loss: 0.0684 - precision_m: 0.9293 - recall_m: 0.9273
# Epoch 33: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_33.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 7347334.5000 - FP: 7134811.0000 - TN: 363684576.0000 - TP: 94215448.0000 - accuracy: 0.9694 - f1_m: 0.9282 - jaccard_score: 0.8664 - loss: 0.0684 - precision_m: 0.9293 - recall_m: 0.9273 - val_FN: 8349714.0000 - val_FP: 3992140.0000 - val_TN: 183050544.0000 - val_TP: 40537228.0000 - val_accuracy: 0.9477 - val_f1_m: 0.8658 - val_jaccard_score: 0.7655 - val_loss: 0.1160 - val_precision_m: 0.9094 - val_recall_m: 0.8278
# Epoch 34/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7248453.5000 - FP: 7058769.0000 - TN: 363920544.0000 - TP: 93631368.0000 - accuracy: 0.9696 - f1_m: 0.9285 - jaccard_score: 0.8669 - loss: 0.0681 - precision_m: 0.9294 - recall_m: 0.9278
# Epoch 34: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_34.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 7256511.5000 - FP: 7066590.5000 - TN: 364323104.0000 - TP: 93736056.0000 - accuracy: 0.9696 - f1_m: 0.9285 - jaccard_score: 0.8669 - loss: 0.0681 - precision_m: 0.9294 - recall_m: 0.9278 - val_FN: 8014277.0000 - val_FP: 4263602.0000 - val_TN: 182779040.0000 - val_TP: 40872656.0000 - val_accuracy: 0.9480 - val_f1_m: 0.8674 - val_jaccard_score: 0.7680 - val_loss: 0.1147 - val_precision_m: 0.9045 - val_recall_m: 0.8347
# Epoch 35/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7144192.0000 - FP: 6950983.0000 - TN: 363216544.0000 - TP: 94547424.0000 - accuracy: 0.9701 - f1_m: 0.9303 - jaccard_score: 0.8700 - loss: 0.0667 - precision_m: 0.9311 - recall_m: 0.9296
# Epoch 35: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_35.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 7152252.0000 - FP: 6958774.0000 - TN: 363620064.0000 - TP: 94651208.0000 - accuracy: 0.9701 - f1_m: 0.9303 - jaccard_score: 0.8700 - loss: 0.0667 - precision_m: 0.9311 - recall_m: 0.9296 - val_FN: 7634484.0000 - val_FP: 4603028.0000 - val_TN: 182439648.0000 - val_TP: 41252456.0000 - val_accuracy: 0.9481 - val_f1_m: 0.8688 - val_jaccard_score: 0.7702 - val_loss: 0.1143 - val_precision_m: 0.8985 - val_recall_m: 0.8424
# Epoch 36/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 7063752.0000 - FP: 6880458.5000 - TN: 363250592.0000 - TP: 94664352.0000 - accuracy: 0.9705 - f1_m: 0.9316 - jaccard_score: 0.8723 - loss: 0.0656 - precision_m: 0.9325 - recall_m: 0.9308
# Epoch 36: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_36.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 174s 193ms/step - FN: 7071658.0000 - FP: 6888114.5000 - TN: 363654240.0000 - TP: 94768248.0000 - accuracy: 0.9705 - f1_m: 0.9316 - jaccard_score: 0.8723 - loss: 0.0656 - precision_m: 0.9325 - recall_m: 0.9308 - val_FN: 7659951.0000 - val_FP: 4463684.0000 - val_TN: 182578896.0000 - val_TP: 41227008.0000 - val_accuracy: 0.9486 - val_f1_m: 0.8699 - val_jaccard_score: 0.7718 - val_loss: 0.1130 - val_precision_m: 0.9012 - val_recall_m: 0.8419
# Epoch 37/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 6870221.5000 - FP: 6712540.0000 - TN: 364290368.0000 - TP: 93985968.0000 - accuracy: 0.9713 - f1_m: 0.9325 - jaccard_score: 0.8738 - loss: 0.0647 - precision_m: 0.9332 - recall_m: 0.9319
# Epoch 37: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_37.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 6877988.5000 - FP: 6720107.0000 - TN: 364693152.0000 - TP: 94090968.0000 - accuracy: 0.9713 - f1_m: 0.9325 - jaccard_score: 0.8738 - loss: 0.0647 - precision_m: 0.9332 - recall_m: 0.9319 - val_FN: 8047167.0000 - val_FP: 4129499.0000 - val_TN: 182913184.0000 - val_TP: 40839772.0000 - val_accuracy: 0.9484 - val_f1_m: 0.8683 - val_jaccard_score: 0.7693 - val_loss: 0.1144 - val_precision_m: 0.9072 - val_recall_m: 0.8340
# Epoch 38/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 6800058.0000 - FP: 6630807.0000 - TN: 363872608.0000 - TP: 94555816.0000 - accuracy: 0.9718 - f1_m: 0.9340 - jaccard_score: 0.8763 - loss: 0.0635 - precision_m: 0.9348 - recall_m: 0.9332
# Epoch 38: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_38.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 6807715.5000 - FP: 6638264.5000 - TN: 364276064.0000 - TP: 94660376.0000 - accuracy: 0.9718 - f1_m: 0.9340 - jaccard_score: 0.8763 - loss: 0.0635 - precision_m: 0.9348 - recall_m: 0.9332 - val_FN: 7835223.0000 - val_FP: 4290270.0000 - val_TN: 182752464.0000 - val_TP: 41051704.0000 - val_accuracy: 0.9486 - val_f1_m: 0.8693 - val_jaccard_score: 0.7709 - val_loss: 0.1141 - val_precision_m: 0.9045 - val_recall_m: 0.8383
# Epoch 39/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6670975.0000 - FP: 6514175.5000 - TN: 364900032.0000 - TP: 93773992.0000 - accuracy: 0.9724 - f1_m: 0.9345 - jaccard_score: 0.8772 - loss: 0.0629 - precision_m: 0.9351 - recall_m: 0.9339
# Epoch 39: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_39.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 6678592.5000 - FP: 6521588.0000 - TN: 365302528.0000 - TP: 93879608.0000 - accuracy: 0.9724 - f1_m: 0.9345 - jaccard_score: 0.8772 - loss: 0.0629 - precision_m: 0.9351 - recall_m: 0.9339 - val_FN: 7626805.0000 - val_FP: 4322800.0000 - val_TN: 182719888.0000 - val_TP: 41260124.0000 - val_accuracy: 0.9494 - val_f1_m: 0.8714 - val_jaccard_score: 0.7743 - val_loss: 0.1122 - val_precision_m: 0.9041 - val_recall_m: 0.8425
# Epoch 40/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6617712.5000 - FP: 6441905.5000 - TN: 364631808.0000 - TP: 94167776.0000 - accuracy: 0.9724 - f1_m: 0.9351 - jaccard_score: 0.8784 - loss: 0.0625 - precision_m: 0.9360 - recall_m: 0.9344
# Epoch 40: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_40.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 6625243.0000 - FP: 6449238.0000 - TN: 365034752.0000 - TP: 94273096.0000 - accuracy: 0.9724 - f1_m: 0.9351 - jaccard_score: 0.8784 - loss: 0.0625 - precision_m: 0.9360 - recall_m: 0.9344 - val_FN: 7428221.0000 - val_FP: 4531723.0000 - val_TN: 182510944.0000 - val_TP: 41458736.0000 - val_accuracy: 0.9493 - val_f1_m: 0.8720 - val_jaccard_score: 0.7751 - val_loss: 0.1123 - val_precision_m: 0.9003 - val_recall_m: 0.8466
# Epoch 41/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6584991.5000 - FP: 6438128.0000 - TN: 363860608.0000 - TP: 94975552.0000 - accuracy: 0.9725 - f1_m: 0.9358 - jaccard_score: 0.8795 - loss: 0.0621 - precision_m: 0.9365 - recall_m: 0.9352
# Epoch 41: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_41.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 6592243.5000 - FP: 6445199.5000 - TN: 364264672.0000 - TP: 95080288.0000 - accuracy: 0.9725 - f1_m: 0.9358 - jaccard_score: 0.8795 - loss: 0.0621 - precision_m: 0.9365 - recall_m: 0.9352 - val_FN: 7388309.0000 - val_FP: 4557617.0000 - val_TN: 182485072.0000 - val_TP: 41498624.0000 - val_accuracy: 0.9494 - val_f1_m: 0.8723 - val_jaccard_score: 0.7756 - val_loss: 0.1124 - val_precision_m: 0.9000 - val_recall_m: 0.8476
# Epoch 42/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6445897.5000 - FP: 6287168.0000 - TN: 364163488.0000 - TP: 94962496.0000 - accuracy: 0.9730 - f1_m: 0.9370 - jaccard_score: 0.8817 - loss: 0.0610 - precision_m: 0.9378 - recall_m: 0.9363
# Epoch 42: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_42.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 6453126.5000 - FP: 6294268.5000 - TN: 364567360.0000 - TP: 95067424.0000 - accuracy: 0.9730 - f1_m: 0.9370 - jaccard_score: 0.8817 - loss: 0.0610 - precision_m: 0.9378 - recall_m: 0.9363 - val_FN: 6934964.0000 - val_FP: 4867738.0000 - val_TN: 182174928.0000 - val_TP: 41951968.0000 - val_accuracy: 0.9500 - val_f1_m: 0.8747 - val_jaccard_score: 0.7794 - val_loss: 0.1110 - val_precision_m: 0.8949 - val_recall_m: 0.8568
# Epoch 43/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6512949.0000 - FP: 6341743.5000 - TN: 363675264.0000 - TP: 95329352.0000 - accuracy: 0.9726 - f1_m: 0.9363 - jaccard_score: 0.8804 - loss: 0.0617 - precision_m: 0.9372 - recall_m: 0.9355
# Epoch 43: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_43.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 6520051.0000 - FP: 6348668.0000 - TN: 364079808.0000 - TP: 95433928.0000 - accuracy: 0.9726 - f1_m: 0.9363 - jaccard_score: 0.8804 - loss: 0.0617 - precision_m: 0.9372 - recall_m: 0.9355 - val_FN: 7580243.0000 - val_FP: 4296340.0000 - val_TN: 182746336.0000 - val_TP: 41306688.0000 - val_accuracy: 0.9497 - val_f1_m: 0.8722 - val_jaccard_score: 0.7756 - val_loss: 0.1121 - val_precision_m: 0.9047 - val_recall_m: 0.8435
# Epoch 44/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6300230.0000 - FP: 6172326.5000 - TN: 364299104.0000 - TP: 95087856.0000 - accuracy: 0.9736 - f1_m: 0.9382 - jaccard_score: 0.8837 - loss: 0.0601 - precision_m: 0.9387 - recall_m: 0.9377
# Epoch 44: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_44.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 192ms/step - FN: 6307341.0000 - FP: 6179256.5000 - TN: 364703104.0000 - TP: 95192928.0000 - accuracy: 0.9736 - f1_m: 0.9382 - jaccard_score: 0.8837 - loss: 0.0601 - precision_m: 0.9387 - recall_m: 0.9377 - val_FN: 7130443.0000 - val_FP: 4613578.0000 - val_TN: 182429136.0000 - val_TP: 41756484.0000 - val_accuracy: 0.9502 - val_f1_m: 0.8748 - val_jaccard_score: 0.7795 - val_loss: 0.1107 - val_precision_m: 0.8994 - val_recall_m: 0.8528
# Epoch 45/45
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 6236121.0000 - FP: 6102944.5000 - TN: 364923680.0000 - TP: 94596576.0000 - accuracy: 0.9739 - f1_m: 0.9385 - jaccard_score: 0.8843 - loss: 0.0597 - precision_m: 0.9390 - recall_m: 0.9381
# Epoch 45: saving model to /kaggle/working/output/_densenet_v5T42025-08-01 12:49:51/keras/_densenet_v5T42025-08-01 12:49:51_1st_45.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 173s 193ms/step - FN: 6243111.5000 - FP: 6109750.0000 - TN: 365327200.0000 - TP: 94702376.0000 - accuracy: 0.9739 - f1_m: 0.9385 - jaccard_score: 0.8843 - loss: 0.0597 - precision_m: 0.9390 - recall_m: 0.9381 - val_FN: 8175239.0000 - val_FP: 3904508.0000 - val_TN: 183138176.0000 - val_TP: 40711700.0000 - val_accuracy: 0.9488 - val_f1_m: 0.8687 - val_jaccard_score: 0.7701 - val_loss: 0.1148 - val_precision_m: 0.9117 - val_recall_m: 0.8313

# %%
import os
import pandas as pd
df = pd.read_csv("training_log.csv")
print(df.head())
# Out:
#    epoch          FN          FP           TN           TP  accuracy  \
# 0      0  51951056.0  82601328.0  657718912.0  150398384.0  0.857265
# 1      1  47208444.0  54913640.0  685406656.0  155140992.0  0.891668
# 2      2  42829272.0  47182112.0  693138496.0  159520224.0  0.904514
# 3      3  39332256.0  40806928.0  699513024.0  163017056.0  0.914987
# 4      4  36422644.0  36741604.0  703579008.0  165926752.0  0.922387
#
#        f1_m  jaccard_score      loss  precision_m  ...      val_FN     val_FP  \
# 0  0.691194       0.533192  0.261603     0.650469  ...  18170396.0  6841729.0
# 1  0.750017       0.602590  0.208050     0.735015  ...  13140079.0  8910188.0
# 2  0.777761       0.638615  0.186267     0.768609  ...  14441355.0  5924799.0
# 3  0.800594       0.669569  0.168675     0.796596  ...  12277599.0  7112409.0
# 4  0.817353       0.693049  0.155779     0.815864  ...  10190260.0  7596250.0
#
#         val_TN      val_TP  val_accuracy  val_f1_m  val_jaccard_score  \
# 0  180200992.0  30716550.0      0.893985  0.703528           0.546825
# 1  178132400.0  35746860.0      0.906538  0.759606           0.615441
# 2  181117824.0  34445572.0      0.913677  0.767007           0.625193
# 3  179930256.0  36609328.0      0.917815  0.787347           0.651695
# 4  179446352.0  38696672.0      0.924611  0.810163           0.683111
#
#    val_loss  val_precision_m  val_recall_m
# 0  0.230742         0.815888      0.623590
# 1  0.194732         0.798879      0.727499
# 2  0.186192         0.852151      0.700435
# 3  0.174018         0.836058      0.746255
# 4  0.157337         0.834431      0.788861
#
# [5 rows x 21 columns]

# %%
timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')


drive_folder = tensor_log_path
os.makedirs(drive_folder, exist_ok=True)


# It saves locally in Colab as 'training_log.csv'
local_csv_path = 'training_log.csv'
drive_csv_path = os.path.join(drive_folder, f'training_log_{timestamp}.csv')

if os.path.exists(local_csv_path):
    shutil.copy(local_csv_path, drive_csv_path)
    print(f"Copied existing CSVLogger file to: {drive_csv_path}")

#If we have a DataFrame named `df` (e.g., from TensorBoard logs)
# Save it directly
try:
    df.to_csv(drive_csv_path, index=False)
    print(f"Saved DataFrame to: {drive_csv_path}")
except NameError:
    print("No DataFrame named 'df' found. Skipping direct save.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/3651036472.py in <cell line: 0>()
# ----> 1 timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
#       2
#       3
#       4 drive_folder = tensor_log_path
#       5 os.makedirs(drive_folder, exist_ok=True)
#
# NameError: name 'datetime' is not defined

# %%
def visualize_predictions(generator, model, num_images=5, save_dir=out_path):
    os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist

    for i in range(num_images):
        X_batch, Y_batch = generator[i]
        preds = (model.predict(X_batch) > 0.5).astype("int32")

        fig, axs = plt.subplots(1, 3, figsize=(6, 2))

        axs[0].imshow(X_batch[0])
        axs[0].set_title("Original Image")

        axs[1].imshow(Y_batch[0].squeeze(), cmap='gray')
        axs[1].set_title("Ground Truth Mask")

        axs[2].imshow(preds[0].squeeze(), cmap='gray')
        axs[2].set_title("Predicted Mask")

        # Remove axes for clarity
        for ax in axs:
            ax.axis('off')

        # Save figure
        fig_path = os.path.join(save_dir, f"prediction_{i+1}.png")
        plt.savefig(fig_path, bbox_inches='tight')
        #plt.close(fig)

        # Display inline
        plt.show(fig)

        # Optional: close to free memory
        plt.close(fig)
        print(f"Saved: {fig_path}")

# Run Visualization
visualize_predictions(val_gen, model, num_images=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/2078040020.py in <cell line: 0>()
# ----> 1 def visualize_predictions(generator, model, num_images=5, save_dir=out_path):
#       2     os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist
#       3
#       4     for i in range(num_images):
#       5         X_batch, Y_batch = generator[i]
#
# NameError: name 'out_path' is not defined

# %%
import os

root_dir = '/kaggle/working'

for root, dirs, files in os.walk(root_dir):
    level = root.replace(root_dir, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")
# Out:
# working/
#     .virtual_documents/
#     tensorboard/
#         log/
#             fit_20250801-124959/
#                 validation/
#                     events.out.tfevents.1754053197.c9d9347db4da.36.1.v2
#                 train/
#                     events.out.tfevents.1754052600.c9d9347db4da.36.0.v2
#     output/
#         _densenet_v5T42025-08-01 12:49:51/
#             training_log.csv
#             keras/
#                 _densenet_v5T42025-08-01 12:49:51_1st_30.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_18.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_08.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_01.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_12.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_21.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_13.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_16.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_29.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_02.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_09.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_28.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_45.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_35.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_39.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_03.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_23.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_43.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_04.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_17.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_15.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_31.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_38.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_37.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_36.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_20.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_40.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_25.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_05.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_32.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_42.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_27.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_34.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_14.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_41.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_19.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_24.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_22.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_07.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_33.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_26.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_10.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_06.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_44.keras
#                 _densenet_v5T42025-08-01 12:49:51_1st_11.keras
