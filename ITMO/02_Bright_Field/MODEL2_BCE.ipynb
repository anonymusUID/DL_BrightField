# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/ITMO/02_Bright_Field')

# %%
import numpy as np
import os
import datetime
import pandas as pd
import shutil

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import Sequence
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
import tensorflow as tf
import tensorflow.keras.backend as K

from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

#from Unet_Resnet_Vgg16_others import Unet_Resnet_Vgg16



mol= '_008vggDICEOvrSmpHard_'

# Parameters
PATCH_SIZE = 256
NUM_CHANNELS = 3
NUM_CLASSES = 1
BATCH_SIZE = 16
NUM_EPOC= 45
dt_tm=datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
sys_info=dt_tm
file_Sig=mol+dt_tm



patches_dir = "/content/gdrive/MyDrive/ITMO/01_BRIGHT_FIELD/857x21"

out_path= '/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_Output_Files/'+file_Sig+'/'
tensor_path='/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_TensorBoard/'+file_Sig+'/'
tensor_log_path='/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_TensorBoard/'+file_Sig+'/log/'
keras_path='/content/gdrive/MyDrive/ITMO/008_OUTPUT/008_Keras/'+file_Sig+"/"

keras_file=keras_path+file_Sig+'.keras'

os.makedirs(os.path.join(out_path, 'images'), exist_ok=True)
os.makedirs(keras_path, exist_ok=True)
os.makedirs(tensor_log_path, exist_ok=True)

print(f"File Signature:{file_Sig} indicates file/folder name")
# Out:
# 2025-08-02 15:30:47.560010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754148647.934365      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754148648.041545      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# File Signature:_008vggDICEOvrSmpHard_2025-08-02 15:31:04 indicates file/folder name

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv2D, UpSampling2D, BatchNormalization, Activation,
                                     Dropout, Add, Multiply, concatenate)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
import tensorflow.keras.backend as K

# ------------------- Enable Mixed Precision -------------------
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# ------------------- Attention Gate -------------------
def attention_gate(x, g, inter_channels):
    theta_x = Conv2D(inter_channels, (1, 1), padding='same')(x)
    phi_g = Conv2D(inter_channels, (1, 1), padding='same')(g)
    add = Add()([theta_x, phi_g])
    act = Activation('relu')(add)
    psi = Conv2D(1, (1, 1), padding='same')(act)
    sigmoid = Activation('sigmoid')(psi)
    out = Multiply()([x, sigmoid])
    return out


# ------------------- Conv Block -------------------
def conv_block(x, filters, dropout_rate=0.1):
    x = Conv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    return x

# ------------------- Decoder Block with Attention -------------------
def decoder_block_attention(x, skip, filters):
    g = UpSampling2D((2, 2))(x)
    att = attention_gate(skip, g, filters // 2)
    x = concatenate([g, att])
    x = conv_block(x, filters)
    return x

# ------------------- Build IAUNet (VGG16) -------------------
def build_iaunet_VERSION_REDUCED(input_shape=(256, 256, 3), num_classes=1, trainable_encoder=False):
    inputs = Input(shape=input_shape)

    # ---- Encoder (VGG16) ----
    vgg = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)
    vgg.trainable = False #trainable_encoder

    """
    # Freeze first 10 layers and unfreeze last 10 layers
    total_layers = len(vgg.layers)
    print("******",total_layers)
    for i, layer in enumerate(vgg.layers):
        if i < total_layers - 10:  # First layers (except last 10)
            layer.trainable = False
        else:  # Last 10 layers
            layer.trainable = True
    """
    skips = [
        vgg.get_layer("block1_conv2").output,  # 256x256
        vgg.get_layer("block2_conv2").output,  # 128x128
        vgg.get_layer("block3_conv3").output,  # 64x64
        vgg.get_layer("block4_conv3").output   # 32x32
    ]
    bridge = vgg.get_layer("block5_conv3").output  # 16x16

    # ---- Decoder (reduced filters for memory efficiency) ----
    d1 = decoder_block_attention(bridge, skips[3], 256)  # 16 → 32
    d2 = decoder_block_attention(d1, skips[2], 128)      # 32 → 64
    d3 = decoder_block_attention(d2, skips[1], 64)       # 64 → 128
    d4 = decoder_block_attention(d3, skips[0], 32)       # 128 → 256

    # Output (no over-upsampling)
    output = Conv2D(num_classes, (1, 1), activation='sigmoid', dtype='float32', name='segmentation_output')(d4)

    return Model(inputs, output, name='IAUNet_VGG16_T4Friendly')


# Example usage:
model = build_iaunet_VERSION_REDUCED()
print("Total params:", model.count_params())
print("Trainable params:", sum(tf.keras.backend.count_params(p) for p in model.trainable_weights))

# Debug print for attention and IA layers
print("\nAttention layers params:")
for layer in model.layers:
    if 'attn' in layer.name:
        print(f"{layer.name}: {layer.count_params()} params")

print("\nInstance Activation layers params:")
for layer in model.layers:
    if 'ia' in layer.name:
        print(f"{layer.name}: {layer.count_params()} params")
# Out:
# I0000 00:00:1754148666.534261      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1754148666.534890      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Total params: 18811125
# Trainable params: 4094517
#
# Attention layers params:
#
# Instance Activation layers params:

# %%
################---Patch Generator For Training---###################
class PatchDataGenerator(Sequence):
    def __init__(self, patches_dir, indices=None, batch_size=BATCH_SIZE, img_size=PATCH_SIZE, **kwargs):  # ✅ Include **kwargs here
        super().__init__(**kwargs)  # ✅ Now this works
        self.batch_size = batch_size
        self.img_size = img_size
        self.image_files = sorted([os.path.join(patches_dir, 'images', fname) for fname in os.listdir(os.path.join(patches_dir, 'images'))])
        self.mask_files = sorted([os.path.join(patches_dir, 'masks', fname) for fname in os.listdir(os.path.join(patches_dir, 'masks'))])
        if indices is not None:
            self.image_files = [self.image_files[i] for i in indices]
            self.mask_files = [self.mask_files[i] for i in indices]
        self.indices = np.arange(len(self.image_files))

    def __len__(self):
        return len(self.image_files) // self.batch_size

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = np.array([np.load(self.image_files[i]) for i in batch_indices])
        Y_batch = np.array([np.load(self.mask_files[i]) for i in batch_indices])
        return X_batch, Y_batch


################## --- Find Hard Patches ---####################
def find_hard_patches(generator, model, threshold=0.3):
    hard_indices = []
    for i in range(len(generator)):
        x_batch, y_batch = generator[i]
        preds = model.predict(x_batch)

        #  Problematic line:
        # error_map = np.abs(preds - y_batch).mean(axis=3)  # <-- only valid if shape is (B, H, W, C)

        #  Fix:
        if preds.ndim == 4:
            error_map = np.abs(preds - y_batch).mean(axis=3)  # Assuming shape: (B, H, W, 1)
        elif preds.ndim == 3:
            error_map = np.abs(preds - y_batch).mean(axis=2)  # (B, H, W)
        else:
            raise ValueError(f"Unexpected prediction shape: {preds.shape}")

        patch_errors = error_map.mean(axis=(1, 2))  # Mean error per image
        for j, err in enumerate(patch_errors):
            if err > threshold:
                hard_indices.append(generator.indices[i * generator.batch_size + j])
    return hard_indices


################## --- Oversample ---#######################
def oversample_generator(train_indices, hard_patches, multiplier=2):
    """
    Oversample hard patches and combine with train_indices.
    """
    # Ensure they're numpy arrays
    train_indices = np.array(train_indices)
    hard_patches = np.array(hard_patches)

    # Oversample hard patches
    repeated_hard = np.tile(hard_patches, multiplier)

    # Combine and shuffle
    combined = np.concatenate([train_indices, repeated_hard])
    np.random.shuffle(combined)

    return combined.tolist()



################## ---Metrics and Loss ---####################

def jaccard_score(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    y_pred = K.round(y_pred)  # Convert probabilities to binary predictions (0 or 1)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + K.epsilon()) / (union + K.epsilon())  # Add epsilon to avoid division by zero


def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def dice_loss(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    return 1 - (2. * intersection + K.epsilon()) / (K.sum(y_true) + K.sum(y_pred) + K.epsilon())

def dice_bce_loss(y_true, y_pred, bce_weight=0.5, smooth=1e-6):
    # Dice Loss
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    # Weighted BCE (no manual weight needed if using class weights)
    bce_loss = K.binary_crossentropy(y_true, y_pred)

    # Combined Loss
    return bce_weight * bce_loss + (1 - bce_weight) * dice_loss

def weighted_binary_crossentropy(y_true, y_pred):
    weight = 10  # Adjust the weight based on the class imbalance
    bce = K.binary_crossentropy(y_true, y_pred)
    weighted_bce = weight * y_true * bce + (1 - y_true) * bce
    return K.mean(weighted_bce)


def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred) - (1 - y_true) * K.log(1 - y_pred)
        weight = alpha * K.pow(1 - y_pred, gamma) * y_true + (1 - alpha) * K.pow(y_pred, gamma) * (1 - y_true)
        loss = weight * cross_entropy
        return K.mean(loss)
    return focal_loss_fixed

def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def boundary_loss(y_true, y_pred):
    # Approximate boundary loss using Laplacian filter on y_pred and y_true
    def laplacian_kernel():
        return tf.constant([[0., 1., 0.],
                            [1., -4., 1.],
                            [0., 1., 0.]], shape=(3, 3, 1, 1), dtype=tf.float32)

    kernel = laplacian_kernel()
    y_true_edge = tf.nn.conv2d(y_true, kernel, strides=1, padding='SAME')
    y_pred_edge = tf.nn.conv2d(y_pred, kernel, strides=1, padding='SAME')
    diff = tf.abs(y_true_edge - y_pred_edge)
    return K.mean(diff)

def focal_dice_boundary_loss(y_true, y_pred, alpha=0.25, gamma=2.0, bce_weight=0.3, boundary_weight=0.1):
    fl = focal_loss(gamma=gamma, alpha=alpha)(y_true, y_pred)
    dl = dice_loss(y_true, y_pred)
    bl = boundary_loss(y_true, y_pred)
    return bce_weight * fl + (1 - bce_weight - boundary_weight) * dl + boundary_weight * bl

# Compile Model
#model = Unet_Resnet_Vgg16(backbone="vgg16")
model = build_iaunet_VERSION_REDUCED()
#for layer in model.layers[-20:]:
    #layer.trainable = True


from tensorflow.keras.optimizers.schedules import ExponentialDecay
lr_schedule1 = ExponentialDecay(
    initial_learning_rate=1e-4,
    decay_steps=9000, #10000
    decay_rate=0.9
)

model.compile(
    optimizer=Adam(learning_rate=lr_schedule1),  # Explicitly set learning rate
    loss= dice_bce_loss,  # binary_crossentropy or dice_loss
    metrics=[
        tf.keras.metrics.TruePositives(name="TP"),
        tf.keras.metrics.FalsePositives(name="FP"),
        tf.keras.metrics.TrueNegatives(name="TN"),
        tf.keras.metrics.FalseNegatives(name="FN"),
        'accuracy',
        recall_m,
        precision_m,
        f1_m,
        jaccard_score
    ]
)
#model.summary()

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Data Split
image_files = sorted([os.path.join(patches_dir, 'images', fname) for fname in os.listdir(os.path.join(patches_dir, 'images'))])
mask_files = sorted([os.path.join(patches_dir, 'masks', fname) for fname in os.listdir(os.path.join(patches_dir, 'masks'))])
train_indices, val_indices = train_test_split(np.arange(len(image_files)), test_size=0.2, random_state=42)

train_gen = PatchDataGenerator(patches_dir, indices=train_indices, batch_size=BATCH_SIZE)
val_gen = PatchDataGenerator(patches_dir, indices=val_indices, batch_size=BATCH_SIZE)


# Callbacks
log_dir = "logs/fit/kan_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True, update_freq='epoch' )
#checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(keras_file, save_best_only=True)
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=keras_path+file_Sig+"_1st_{epoch:02d}.keras",  # dynamic naming
    save_freq='epoch',
    save_weights_only=False,  # Save the full model (not just weights)
    save_best_only=False,     # Save all epochs (not just the best one)
    verbose=1
)




csv_logger = tf.keras.callbacks.CSVLogger("training_log.csv", append=True)
# Train with more epochs
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=NUM_EPOC,
    callbacks=[csv_logger, tensorboard_callback, checkpoint_callback, early_stopping],
    verbose=1,
    #workers=4,
    #use_multiprocessing=True,
    #max_queue_size=10
)
print("First training phase metrics/epochs:")
print(history.history)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754148688.085796      95 service.cc:148] XLA service 0x7d9458003680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754148688.087656      95 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754148688.087677      95 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754148690.071877      95 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-08-02 15:31:52.855189: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[16,256,256,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[32,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:31:54.174775: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.319694143s
# Trying algorithm eng0{} for conv (f16[16,256,256,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[32,3,3,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:00.107239: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[256,3,3,1024]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,1024]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:00.631494: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.52433279s
# Trying algorithm eng19{k2=2} for conv (f16[256,3,3,1024]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,1024]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:01.631709: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[256,3,3,1024]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,1024]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:02.125519: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.493919692s
# Trying algorithm eng19{k2=3} for conv (f16[256,3,3,1024]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,1024]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:03.125800: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[256,3,3,1024]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,1024]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:03.718743: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.593117416s
# Trying algorithm eng19{k2=0} for conv (f16[256,3,3,1024]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,32,32,1024]{3,2,1,0}, f16[16,32,32,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:07.422291: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[128,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,512]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:11.423298: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 5.001076509s
# Trying algorithm eng19{k2=2} for conv (f16[128,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,512]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:12.423530: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[128,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,512]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:14.523738: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.100323224s
# Trying algorithm eng19{k2=3} for conv (f16[128,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,512]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:15.523964: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[128,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,512]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:21.293188: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.769337576s
# Trying algorithm eng19{k2=0} for conv (f16[128,3,3,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,512]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:24.052883: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,128]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:24.367179: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.314471397s
# Trying algorithm eng19{k2=0} for conv (f16[128,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,64,64,128]{3,2,1,0}, f16[16,64,64,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:27.353866: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:34.320398: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 7.966648592s
# Trying algorithm eng19{k2=3} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:35.320587: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:43.326441: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 9.005942283s
# Trying algorithm eng19{k2=0} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:32:44.326632: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:42.105783: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 58.77923102s
# Trying algorithm eng0{} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:43.105997: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:49.183093: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 7.077192s
# Trying algorithm eng19{k2=2} for conv (f16[64,3,3,256]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,256]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:50.574803: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:50.996278: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.421590357s
# Trying algorithm eng19{k2=3} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:51.996460: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:52.568333: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.571973565s
# Trying algorithm eng19{k2=0} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:53.568513: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:53.948515: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.380094763s
# Trying algorithm eng19{k2=2} for conv (f16[64,3,3,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,128,128,64]{3,2,1,0}, f16[16,128,128,64]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:33:58.739182: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:34:03.896399: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 6.15731093s
# Trying algorithm eng19{k2=2} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:34:04.896624: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:34:11.197197: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 7.30067912s
# Trying algorithm eng19{k2=3} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:34:12.197407: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:34:20.285506: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 9.088185549s
# Trying algorithm eng19{k2=0} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:34:21.285711: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:15.201038: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 54.915415021s
# Trying algorithm eng0{} for conv (f16[32,3,3,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,128]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:16.802574: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=2} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:16.982026: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.179540665s
# Trying algorithm eng19{k2=2} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:17.982182: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=3} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:18.777026: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.79491911s
# Trying algorithm eng19{k2=3} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:19.777220: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng19{k2=0} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:20.203819: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.426694056s
# Trying algorithm eng19{k2=0} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:21.203992: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-08-02 15:35:30.493194: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 10.289288809s
# Trying algorithm eng0{} for conv (f16[32,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,256,256,32]{3,2,1,0}, f16[16,256,256,32]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1754148939.023022      95 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - FN: 27795008.0000 - FP: 40611512.0000 - TN: 330725792.0000 - TP: 72726704.0000 - accuracy: 0.8427 - f1_m: 0.6482 - jaccard_score: 0.4889 - loss: 0.4002 - precision_m: 0.6101 - recall_m: 0.7059
# Epoch 1: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_01.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 857s 655ms/step - FN: 27824094.0000 - FP: 40647852.0000 - TN: 331099456.0000 - TP: 72810752.0000 - accuracy: 0.8427 - f1_m: 0.6483 - jaccard_score: 0.4890 - loss: 0.4001 - precision_m: 0.6101 - recall_m: 0.7060 - val_FN: 11299025.0000 - val_FP: 14239978.0000 - val_TN: 172802656.0000 - val_TP: 37587912.0000 - val_accuracy: 0.8918 - val_f1_m: 0.7427 - val_jaccard_score: 0.5934 - val_loss: 0.2828 - val_precision_m: 0.7241 - val_recall_m: 0.7660
# Epoch 2/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 24388112.0000 - FP: 27062858.0000 - TN: 342749184.0000 - TP: 77659112.0000 - accuracy: 0.8900 - f1_m: 0.7470 - jaccard_score: 0.5986 - loss: 0.2880 - precision_m: 0.7355 - recall_m: 0.7644
# Epoch 2: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_02.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 175s 194ms/step - FN: 24414638.0000 - FP: 27091570.0000 - TN: 343132128.0000 - TP: 77744032.0000 - accuracy: 0.8900 - f1_m: 0.7470 - jaccard_score: 0.5987 - loss: 0.2880 - precision_m: 0.7355 - recall_m: 0.7644 - val_FN: 11107779.0000 - val_FP: 11901031.0000 - val_TN: 175141552.0000 - val_TP: 37779176.0000 - val_accuracy: 0.9025 - val_f1_m: 0.7633 - val_jaccard_score: 0.6197 - val_loss: 0.2598 - val_precision_m: 0.7599 - val_recall_m: 0.7696
# Epoch 3/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 22250294.0000 - FP: 23875556.0000 - TN: 346760768.0000 - TP: 78972576.0000 - accuracy: 0.9016 - f1_m: 0.7705 - jaccard_score: 0.6290 - loss: 0.2592 - precision_m: 0.7637 - recall_m: 0.7820
# Epoch 3: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_03.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 22274386.0000 - FP: 23901400.0000 - TN: 347145696.0000 - TP: 79060848.0000 - accuracy: 0.9017 - f1_m: 0.7705 - jaccard_score: 0.6290 - loss: 0.2592 - precision_m: 0.7637 - recall_m: 0.7820 - val_FN: 11802935.0000 - val_FP: 9162089.0000 - val_TN: 177880608.0000 - val_TP: 37084008.0000 - val_accuracy: 0.9111 - val_f1_m: 0.7762 - val_jaccard_score: 0.6368 - val_loss: 0.2420 - val_precision_m: 0.8012 - val_recall_m: 0.7555
# Epoch 4/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 20349542.0000 - FP: 21743502.0000 - TN: 348974624.0000 - TP: 80791648.0000 - accuracy: 0.9100 - f1_m: 0.7896 - jaccard_score: 0.6545 - loss: 0.2381 - precision_m: 0.7829 - recall_m: 0.7997
# Epoch 4: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_04.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 20371594.0000 - FP: 21766962.0000 - TN: 349361856.0000 - TP: 80882048.0000 - accuracy: 0.9100 - f1_m: 0.7896 - jaccard_score: 0.6545 - loss: 0.2380 - precision_m: 0.7829 - recall_m: 0.7997 - val_FN: 9990256.0000 - val_FP: 9670697.0000 - val_TN: 177372032.0000 - val_TP: 38896708.0000 - val_accuracy: 0.9167 - val_f1_m: 0.7950 - val_jaccard_score: 0.6623 - val_loss: 0.2244 - val_precision_m: 0.7990 - val_recall_m: 0.7933
# Epoch 5/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 18775370.0000 - FP: 19937608.0000 - TN: 350546944.0000 - TP: 82598968.0000 - accuracy: 0.9178 - f1_m: 0.8075 - jaccard_score: 0.6791 - loss: 0.2190 - precision_m: 0.8026 - recall_m: 0.8154
# Epoch 5: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_05.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 18796144.0000 - FP: 19959560.0000 - TN: 350935936.0000 - TP: 82690392.0000 - accuracy: 0.9178 - f1_m: 0.8075 - jaccard_score: 0.6791 - loss: 0.2190 - precision_m: 0.8026 - recall_m: 0.8154 - val_FN: 9399171.0000 - val_FP: 9569588.0000 - val_TN: 177473184.0000 - val_TP: 39487764.0000 - val_accuracy: 0.9196 - val_f1_m: 0.8030 - val_jaccard_score: 0.6733 - val_loss: 0.2162 - val_precision_m: 0.8035 - val_recall_m: 0.8051
# Epoch 6/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - FN: 17718368.0000 - FP: 18985606.0000 - TN: 351099680.0000 - TP: 84055720.0000 - accuracy: 0.9218 - f1_m: 0.8185 - jaccard_score: 0.6946 - loss: 0.2081 - precision_m: 0.8139 - recall_m: 0.8255
# Epoch 6: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_06.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 195s 217ms/step - FN: 17737722.0000 - FP: 19006212.0000 - TN: 351490432.0000 - TP: 84148120.0000 - accuracy: 0.9218 - f1_m: 0.8185 - jaccard_score: 0.6946 - loss: 0.2081 - precision_m: 0.8139 - recall_m: 0.8255 - val_FN: 9779626.0000 - val_FP: 10537874.0000 - val_TN: 176504816.0000 - val_TP: 39107336.0000 - val_accuracy: 0.9139 - val_f1_m: 0.7896 - val_jaccard_score: 0.6548 - val_loss: 0.2318 - val_precision_m: 0.7855 - val_recall_m: 0.7967
# Epoch 7/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - FN: 16694265.0000 - FP: 17787536.0000 - TN: 353438176.0000 - TP: 83939280.0000 - accuracy: 0.9264 - f1_m: 0.8272 - jaccard_score: 0.7071 - loss: 0.1971 - precision_m: 0.8220 - recall_m: 0.8347
# Epoch 7: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_07.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 181s 201ms/step - FN: 16712870.0000 - FP: 17807270.0000 - TN: 353828544.0000 - TP: 84033696.0000 - accuracy: 0.9264 - f1_m: 0.8272 - jaccard_score: 0.7071 - loss: 0.1971 - precision_m: 0.8220 - recall_m: 0.8347 - val_FN: 8533975.0000 - val_FP: 9719790.0000 - val_TN: 177322832.0000 - val_TP: 40352960.0000 - val_accuracy: 0.9226 - val_f1_m: 0.8132 - val_jaccard_score: 0.6873 - val_loss: 0.2104 - val_precision_m: 0.8051 - val_recall_m: 0.8235
# Epoch 8/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 15862695.0000 - FP: 17044892.0000 - TN: 353292160.0000 - TP: 85659472.0000 - accuracy: 0.9307 - f1_m: 0.8388 - jaccard_score: 0.7240 - loss: 0.1858 - precision_m: 0.8336 - recall_m: 0.8459
# Epoch 8: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_08.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 15880416.0000 - FP: 17063654.0000 - TN: 353684480.0000 - TP: 85753784.0000 - accuracy: 0.9307 - f1_m: 0.8388 - jaccard_score: 0.7240 - loss: 0.1858 - precision_m: 0.8336 - recall_m: 0.8459 - val_FN: 10245301.0000 - val_FP: 7852149.0000 - val_TN: 179190544.0000 - val_TP: 38641624.0000 - val_accuracy: 0.9233 - val_f1_m: 0.8076 - val_jaccard_score: 0.6795 - val_loss: 0.2187 - val_precision_m: 0.8304 - val_recall_m: 0.7883
# Epoch 9/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 15285087.0000 - FP: 16284856.0000 - TN: 354471552.0000 - TP: 85817616.0000 - accuracy: 0.9330 - f1_m: 0.8420 - jaccard_score: 0.7289 - loss: 0.1812 - precision_m: 0.8382 - recall_m: 0.8480
# Epoch 9: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_09.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 15302193.0000 - FP: 16303052.0000 - TN: 354863968.0000 - TP: 85913008.0000 - accuracy: 0.9330 - f1_m: 0.8420 - jaccard_score: 0.7289 - loss: 0.1812 - precision_m: 0.8382 - recall_m: 0.8480 - val_FN: 6388824.0000 - val_FP: 13197014.0000 - val_TN: 173845616.0000 - val_TP: 42498100.0000 - val_accuracy: 0.9170 - val_f1_m: 0.8097 - val_jaccard_score: 0.6824 - val_loss: 0.2154 - val_precision_m: 0.7609 - val_recall_m: 0.8678
# Epoch 10/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 14773532.0000 - FP: 15546197.0000 - TN: 355056224.0000 - TP: 86483432.0000 - accuracy: 0.9356 - f1_m: 0.8493 - jaccard_score: 0.7397 - loss: 0.1743 - precision_m: 0.8463 - recall_m: 0.8542
# Epoch 10: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_10.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 190ms/step - FN: 14789892.0000 - FP: 15563627.0000 - TN: 355449600.0000 - TP: 86579392.0000 - accuracy: 0.9356 - f1_m: 0.8493 - jaccard_score: 0.7397 - loss: 0.1743 - precision_m: 0.8463 - recall_m: 0.8542 - val_FN: 10138132.0000 - val_FP: 6608251.0000 - val_TN: 180434448.0000 - val_TP: 38748816.0000 - val_accuracy: 0.9290 - val_f1_m: 0.8191 - val_jaccard_score: 0.6960 - val_loss: 0.1976 - val_precision_m: 0.8524 - val_recall_m: 0.7902
# Epoch 11/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 13920377.0000 - FP: 14847352.0000 - TN: 356075840.0000 - TP: 87015704.0000 - accuracy: 0.9397 - f1_m: 0.8575 - jaccard_score: 0.7521 - loss: 0.1644 - precision_m: 0.8540 - recall_m: 0.8626
# Epoch 11: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_11.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 13936535.0000 - FP: 14864418.0000 - TN: 356469216.0000 - TP: 87112224.0000 - accuracy: 0.9397 - f1_m: 0.8575 - jaccard_score: 0.7521 - loss: 0.1644 - precision_m: 0.8540 - recall_m: 0.8626 - val_FN: 7730358.0000 - val_FP: 9110033.0000 - val_TN: 177932624.0000 - val_TP: 41156592.0000 - val_accuracy: 0.9286 - val_f1_m: 0.8271 - val_jaccard_score: 0.7074 - val_loss: 0.1932 - val_precision_m: 0.8166 - val_recall_m: 0.8399
# Epoch 12/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 13637257.0000 - FP: 14674509.0000 - TN: 355528576.0000 - TP: 88018968.0000 - accuracy: 0.9398 - f1_m: 0.8601 - jaccard_score: 0.7560 - loss: 0.1624 - precision_m: 0.8558 - recall_m: 0.8659
# Epoch 12: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_12.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 13652600.0000 - FP: 14690779.0000 - TN: 355923552.0000 - TP: 88115512.0000 - accuracy: 0.9398 - f1_m: 0.8601 - jaccard_score: 0.7560 - loss: 0.1624 - precision_m: 0.8558 - recall_m: 0.8659 - val_FN: 7422870.0000 - val_FP: 9376001.0000 - val_TN: 177666640.0000 - val_TP: 41464080.0000 - val_accuracy: 0.9288 - val_f1_m: 0.8288 - val_jaccard_score: 0.7099 - val_loss: 0.1919 - val_precision_m: 0.8136 - val_recall_m: 0.8469
# Epoch 13/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 13350190.0000 - FP: 14243602.0000 - TN: 356796320.0000 - TP: 87469104.0000 - accuracy: 0.9416 - f1_m: 0.8619 - jaccard_score: 0.7589 - loss: 0.1593 - precision_m: 0.8592 - recall_m: 0.8666
# Epoch 13: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_13.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 13365054.0000 - FP: 14259586.0000 - TN: 357190656.0000 - TP: 87567056.0000 - accuracy: 0.9416 - f1_m: 0.8619 - jaccard_score: 0.7589 - loss: 0.1593 - precision_m: 0.8592 - recall_m: 0.8666 - val_FN: 7115941.0000 - val_FP: 9690824.0000 - val_TN: 177351872.0000 - val_TP: 41770988.0000 - val_accuracy: 0.9288 - val_f1_m: 0.8298 - val_jaccard_score: 0.7113 - val_loss: 0.1926 - val_precision_m: 0.8099 - val_recall_m: 0.8531
# Epoch 14/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 12985283.0000 - FP: 13805601.0000 - TN: 356578144.0000 - TP: 88490248.0000 - accuracy: 0.9429 - f1_m: 0.8673 - jaccard_score: 0.7669 - loss: 0.1545 - precision_m: 0.8643 - recall_m: 0.8715
# Epoch 14: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_14.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 176s 196ms/step - FN: 12999646.0000 - FP: 13821045.0000 - TN: 356973728.0000 - TP: 88587968.0000 - accuracy: 0.9429 - f1_m: 0.8673 - jaccard_score: 0.7669 - loss: 0.1545 - precision_m: 0.8643 - recall_m: 0.8715 - val_FN: 6211758.0000 - val_FP: 10939276.0000 - val_TN: 176103392.0000 - val_TP: 42675184.0000 - val_accuracy: 0.9273 - val_f1_m: 0.8302 - val_jaccard_score: 0.7116 - val_loss: 0.1958 - val_precision_m: 0.7941 - val_recall_m: 0.8715
# Epoch 15/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 12644270.0000 - FP: 13653415.0000 - TN: 356455968.0000 - TP: 89105512.0000 - accuracy: 0.9444 - f1_m: 0.8709 - jaccard_score: 0.7726 - loss: 0.1505 - precision_m: 0.8663 - recall_m: 0.8767
# Epoch 15: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_15.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 175s 194ms/step - FN: 12658466.0000 - FP: 13668608.0000 - TN: 356852128.0000 - TP: 89203088.0000 - accuracy: 0.9444 - f1_m: 0.8709 - jaccard_score: 0.7726 - loss: 0.1505 - precision_m: 0.8663 - recall_m: 0.8767 - val_FN: 7854314.0000 - val_FP: 8059749.0000 - val_TN: 178982976.0000 - val_TP: 41032632.0000 - val_accuracy: 0.9325 - val_f1_m: 0.8347 - val_jaccard_score: 0.7185 - val_loss: 0.1853 - val_precision_m: 0.8340 - val_recall_m: 0.8375
# Epoch 16/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 12442591.0000 - FP: 13233147.0000 - TN: 357341152.0000 - TP: 88842200.0000 - accuracy: 0.9454 - f1_m: 0.8718 - jaccard_score: 0.7741 - loss: 0.1485 - precision_m: 0.8688 - recall_m: 0.8761
# Epoch 16: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_16.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 176s 195ms/step - FN: 12455970.0000 - FP: 13247682.0000 - TN: 357737440.0000 - TP: 88941112.0000 - accuracy: 0.9454 - f1_m: 0.8718 - jaccard_score: 0.7741 - loss: 0.1485 - precision_m: 0.8688 - recall_m: 0.8761 - val_FN: 9853028.0000 - val_FP: 5931650.0000 - val_TN: 181110976.0000 - val_TP: 39033924.0000 - val_accuracy: 0.9331 - val_f1_m: 0.8291 - val_jaccard_score: 0.7104 - val_loss: 0.1950 - val_precision_m: 0.8668 - val_recall_m: 0.7963
# Epoch 17/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 12004107.0000 - FP: 13054256.0000 - TN: 357609216.0000 - TP: 89191608.0000 - accuracy: 0.9470 - f1_m: 0.8758 - jaccard_score: 0.7802 - loss: 0.1444 - precision_m: 0.8719 - recall_m: 0.8809
# Epoch 17: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_17.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 12017484.0000 - FP: 13068711.0000 - TN: 358005504.0000 - TP: 89290624.0000 - accuracy: 0.9470 - f1_m: 0.8758 - jaccard_score: 0.7802 - loss: 0.1444 - precision_m: 0.8719 - recall_m: 0.8809 - val_FN: 9135370.0000 - val_FP: 6441234.0000 - val_TN: 180601408.0000 - val_TP: 39751592.0000 - val_accuracy: 0.9340 - val_f1_m: 0.8335 - val_jaccard_score: 0.7167 - val_loss: 0.1892 - val_precision_m: 0.8588 - val_recall_m: 0.8113
# Epoch 18/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 11903680.0000 - FP: 12833888.0000 - TN: 357406176.0000 - TP: 89715352.0000 - accuracy: 0.9474 - f1_m: 0.8780 - jaccard_score: 0.7838 - loss: 0.1428 - precision_m: 0.8739 - recall_m: 0.8833
# Epoch 18: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_18.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 11916828.0000 - FP: 12848048.0000 - TN: 357803200.0000 - TP: 89814128.0000 - accuracy: 0.9474 - f1_m: 0.8780 - jaccard_score: 0.7838 - loss: 0.1428 - precision_m: 0.8739 - recall_m: 0.8833 - val_FN: 5392747.0000 - val_FP: 12795950.0000 - val_TN: 174246688.0000 - val_TP: 43494184.0000 - val_accuracy: 0.9229 - val_f1_m: 0.8246 - val_jaccard_score: 0.7036 - val_loss: 0.2034 - val_precision_m: 0.7709 - val_recall_m: 0.8886
# Epoch 19/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 11286163.0000 - FP: 12340992.0000 - TN: 358524384.0000 - TP: 89707904.0000 - accuracy: 0.9502 - f1_m: 0.8837 - jaccard_score: 0.7926 - loss: 0.1363 - precision_m: 0.8790 - recall_m: 0.8893
# Epoch 19: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_19.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 11299234.0000 - FP: 12355134.0000 - TN: 358920768.0000 - TP: 89807448.0000 - accuracy: 0.9502 - f1_m: 0.8837 - jaccard_score: 0.7926 - loss: 0.1363 - precision_m: 0.8790 - recall_m: 0.8893 - val_FN: 7148097.0000 - val_FP: 8439880.0000 - val_TN: 178602768.0000 - val_TP: 41738840.0000 - val_accuracy: 0.9339 - val_f1_m: 0.8403 - val_jaccard_score: 0.7266 - val_loss: 0.1819 - val_precision_m: 0.8302 - val_recall_m: 0.8523
# Epoch 20/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 11199086.0000 - FP: 12203601.0000 - TN: 358154048.0000 - TP: 90302440.0000 - accuracy: 0.9507 - f1_m: 0.8842 - jaccard_score: 0.7935 - loss: 0.1353 - precision_m: 0.8798 - recall_m: 0.8896
# Epoch 20: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_20.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 178s 197ms/step - FN: 11211691.0000 - FP: 12217242.0000 - TN: 358551488.0000 - TP: 90401888.0000 - accuracy: 0.9507 - f1_m: 0.8842 - jaccard_score: 0.7935 - loss: 0.1353 - precision_m: 0.8798 - recall_m: 0.8896 - val_FN: 8969847.0000 - val_FP: 6514616.0000 - val_TN: 180528064.0000 - val_TP: 39917120.0000 - val_accuracy: 0.9344 - val_f1_m: 0.8351 - val_jaccard_score: 0.7190 - val_loss: 0.1878 - val_precision_m: 0.8584 - val_recall_m: 0.8144
# Epoch 21/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 10832519.0000 - FP: 12012072.0000 - TN: 359000640.0000 - TP: 90013872.0000 - accuracy: 0.9516 - f1_m: 0.8869 - jaccard_score: 0.7978 - loss: 0.1327 - precision_m: 0.8816 - recall_m: 0.8930
# Epoch 21: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_21.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 10844947.0000 - FP: 12025597.0000 - TN: 359397472.0000 - TP: 90114224.0000 - accuracy: 0.9516 - f1_m: 0.8869 - jaccard_score: 0.7978 - loss: 0.1327 - precision_m: 0.8816 - recall_m: 0.8930 - val_FN: 7493260.0000 - val_FP: 7709382.0000 - val_TN: 179333376.0000 - val_TP: 41393676.0000 - val_accuracy: 0.9356 - val_f1_m: 0.8427 - val_jaccard_score: 0.7302 - val_loss: 0.1820 - val_precision_m: 0.8418 - val_recall_m: 0.8453
# Epoch 22/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 10735986.0000 - FP: 11805548.0000 - TN: 358541792.0000 - TP: 90775848.0000 - accuracy: 0.9525 - f1_m: 0.8896 - jaccard_score: 0.8022 - loss: 0.1297 - precision_m: 0.8851 - recall_m: 0.8951
# Epoch 22: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_22.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 10748263.0000 - FP: 11818851.0000 - TN: 358939552.0000 - TP: 90875616.0000 - accuracy: 0.9525 - f1_m: 0.8896 - jaccard_score: 0.8022 - loss: 0.1297 - precision_m: 0.8851 - recall_m: 0.8951 - val_FN: 7151205.0000 - val_FP: 8406882.0000 - val_TN: 178635760.0000 - val_TP: 41735732.0000 - val_accuracy: 0.9341 - val_f1_m: 0.8407 - val_jaccard_score: 0.7272 - val_loss: 0.1832 - val_precision_m: 0.8303 - val_recall_m: 0.8528
# Epoch 23/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 10692292.0000 - FP: 11832578.0000 - TN: 358153280.0000 - TP: 91181104.0000 - accuracy: 0.9521 - f1_m: 0.8889 - jaccard_score: 0.8011 - loss: 0.1307 - precision_m: 0.8843 - recall_m: 0.8944
# Epoch 23: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_23.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 10704098.0000 - FP: 11845575.0000 - TN: 358551744.0000 - TP: 91280936.0000 - accuracy: 0.9521 - f1_m: 0.8889 - jaccard_score: 0.8011 - loss: 0.1307 - precision_m: 0.8843 - recall_m: 0.8944 - val_FN: 7782648.0000 - val_FP: 7419828.0000 - val_TN: 179622816.0000 - val_TP: 41104280.0000 - val_accuracy: 0.9356 - val_f1_m: 0.8416 - val_jaccard_score: 0.7287 - val_loss: 0.1823 - val_precision_m: 0.8458 - val_recall_m: 0.8392
# Epoch 24/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 10385150.0000 - FP: 11492237.0000 - TN: 359249408.0000 - TP: 90732240.0000 - accuracy: 0.9533 - f1_m: 0.8911 - jaccard_score: 0.8046 - loss: 0.1276 - precision_m: 0.8868 - recall_m: 0.8966
# Epoch 24: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_24.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 190ms/step - FN: 10396727.0000 - FP: 11505064.0000 - TN: 359647232.0000 - TP: 90833144.0000 - accuracy: 0.9533 - f1_m: 0.8911 - jaccard_score: 0.8046 - loss: 0.1276 - precision_m: 0.8868 - recall_m: 0.8966 - val_FN: 6835622.0000 - val_FP: 8154729.0000 - val_TN: 178887952.0000 - val_TP: 42051328.0000 - val_accuracy: 0.9365 - val_f1_m: 0.8464 - val_jaccard_score: 0.7357 - val_loss: 0.1770 - val_precision_m: 0.8358 - val_recall_m: 0.8590
# Epoch 25/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 10075492.0000 - FP: 11237539.0000 - TN: 359746464.0000 - TP: 90799744.0000 - accuracy: 0.9552 - f1_m: 0.8951 - jaccard_score: 0.8110 - loss: 0.1233 - precision_m: 0.8900 - recall_m: 0.9010
# Epoch 25: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_25.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 10087018.0000 - FP: 11250304.0000 - TN: 360144096.0000 - TP: 90900968.0000 - accuracy: 0.9552 - f1_m: 0.8951 - jaccard_score: 0.8110 - loss: 0.1233 - precision_m: 0.8900 - recall_m: 0.9010 - val_FN: 7046223.0000 - val_FP: 7864696.0000 - val_TN: 179177904.0000 - val_TP: 41840740.0000 - val_accuracy: 0.9368 - val_f1_m: 0.8465 - val_jaccard_score: 0.7358 - val_loss: 0.1765 - val_precision_m: 0.8397 - val_recall_m: 0.8547
# Epoch 26/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9904617.0000 - FP: 11251394.0000 - TN: 359776032.0000 - TP: 90927256.0000 - accuracy: 0.9551 - f1_m: 0.8949 - jaccard_score: 0.8106 - loss: 0.1232 - precision_m: 0.8890 - recall_m: 0.9016
# Epoch 26: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_26.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 190ms/step - FN: 9915652.0000 - FP: 11263817.0000 - TN: 360173952.0000 - TP: 91029024.0000 - accuracy: 0.9551 - f1_m: 0.8949 - jaccard_score: 0.8106 - loss: 0.1232 - precision_m: 0.8890 - recall_m: 0.9016 - val_FN: 7777979.0000 - val_FP: 7109771.0000 - val_TN: 179932880.0000 - val_TP: 41108976.0000 - val_accuracy: 0.9369 - val_f1_m: 0.8444 - val_jaccard_score: 0.7326 - val_loss: 0.1793 - val_precision_m: 0.8506 - val_recall_m: 0.8394
# Epoch 27/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - FN: 9936583.0000 - FP: 11154900.0000 - TN: 359955136.0000 - TP: 90812704.0000 - accuracy: 0.9556 - f1_m: 0.8953 - jaccard_score: 0.8114 - loss: 0.1226 - precision_m: 0.8899 - recall_m: 0.9016
# Epoch 27: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_27.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 174s 194ms/step - FN: 9947528.0000 - FP: 11167203.0000 - TN: 360353056.0000 - TP: 90914648.0000 - accuracy: 0.9556 - f1_m: 0.8953 - jaccard_score: 0.8114 - loss: 0.1226 - precision_m: 0.8899 - recall_m: 0.9016 - val_FN: 8551474.0000 - val_FP: 6652252.0000 - val_TN: 180390480.0000 - val_TP: 40335448.0000 - val_accuracy: 0.9356 - val_f1_m: 0.8392 - val_jaccard_score: 0.7250 - val_loss: 0.1922 - val_precision_m: 0.8571 - val_recall_m: 0.8233
# Epoch 28/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - FN: 9822028.0000 - FP: 11096065.0000 - TN: 358554720.0000 - TP: 92386392.0000 - accuracy: 0.9556 - f1_m: 0.8980 - jaccard_score: 0.8156 - loss: 0.1211 - precision_m: 0.8927 - recall_m: 0.9041
# Epoch 28: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_28.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 194s 216ms/step - FN: 9832790.0000 - FP: 11108265.0000 - TN: 358954400.0000 - TP: 92486896.0000 - accuracy: 0.9556 - f1_m: 0.8980 - jaccard_score: 0.8156 - loss: 0.1211 - precision_m: 0.8927 - recall_m: 0.9041 - val_FN: 7055406.0000 - val_FP: 7490511.0000 - val_TN: 179552144.0000 - val_TP: 41831532.0000 - val_accuracy: 0.9383 - val_f1_m: 0.8496 - val_jaccard_score: 0.7406 - val_loss: 0.1752 - val_precision_m: 0.8465 - val_recall_m: 0.8541
# Epoch 29/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - FN: 9341416.0000 - FP: 10649098.0000 - TN: 360428608.0000 - TP: 91440040.0000 - accuracy: 0.9578 - f1_m: 0.9011 - jaccard_score: 0.8207 - loss: 0.1167 - precision_m: 0.8950 - recall_m: 0.9077
# Epoch 29: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_29.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 177s 196ms/step - FN: 9352122.0000 - FP: 10661147.0000 - TN: 360826848.0000 - TP: 91542192.0000 - accuracy: 0.9578 - f1_m: 0.9011 - jaccard_score: 0.8207 - loss: 0.1167 - precision_m: 0.8950 - recall_m: 0.9077 - val_FN: 8422555.0000 - val_FP: 6045762.0000 - val_TN: 180996864.0000 - val_TP: 40464380.0000 - val_accuracy: 0.9387 - val_f1_m: 0.8458 - val_jaccard_score: 0.7350 - val_loss: 0.1804 - val_precision_m: 0.8684 - val_recall_m: 0.8257
# Epoch 30/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9332490.0000 - FP: 10589239.0000 - TN: 360464800.0000 - TP: 91472648.0000 - accuracy: 0.9575 - f1_m: 0.9009 - jaccard_score: 0.8204 - loss: 0.1168 - precision_m: 0.8959 - recall_m: 0.9066
# Epoch 30: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_30.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 171s 190ms/step - FN: 9343028.0000 - FP: 10601256.0000 - TN: 360863072.0000 - TP: 91574936.0000 - accuracy: 0.9575 - f1_m: 0.9009 - jaccard_score: 0.8204 - loss: 0.1168 - precision_m: 0.8959 - recall_m: 0.9066 - val_FN: 6775417.0000 - val_FP: 7982677.0000 - val_TN: 179060048.0000 - val_TP: 42111520.0000 - val_accuracy: 0.9374 - val_f1_m: 0.8485 - val_jaccard_score: 0.7388 - val_loss: 0.1751 - val_precision_m: 0.8383 - val_recall_m: 0.8602
# Epoch 31/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9255225.0000 - FP: 10532484.0000 - TN: 359912448.0000 - TP: 92159056.0000 - accuracy: 0.9583 - f1_m: 0.9027 - jaccard_score: 0.8233 - loss: 0.1150 - precision_m: 0.8970 - recall_m: 0.9089
# Epoch 31: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_31.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 9265570.0000 - FP: 10544285.0000 - TN: 360311616.0000 - TP: 92260856.0000 - accuracy: 0.9583 - f1_m: 0.9026 - jaccard_score: 0.8233 - loss: 0.1150 - precision_m: 0.8970 - recall_m: 0.9089 - val_FN: 7701972.0000 - val_FP: 7005714.0000 - val_TN: 180036912.0000 - val_TP: 41184976.0000 - val_accuracy: 0.9377 - val_f1_m: 0.8463 - val_jaccard_score: 0.7357 - val_loss: 0.1805 - val_precision_m: 0.8530 - val_recall_m: 0.8409
# Epoch 32/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8952502.0000 - FP: 10380479.0000 - TN: 360463360.0000 - TP: 92062784.0000 - accuracy: 0.9592 - f1_m: 0.9050 - jaccard_score: 0.8273 - loss: 0.1122 - precision_m: 0.8987 - recall_m: 0.9119
# Epoch 32: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_32.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 190ms/step - FN: 8962869.0000 - FP: 10392204.0000 - TN: 360862176.0000 - TP: 92165008.0000 - accuracy: 0.9592 - f1_m: 0.9050 - jaccard_score: 0.8273 - loss: 0.1122 - precision_m: 0.8987 - recall_m: 0.9119 - val_FN: 7197713.0000 - val_FP: 7283147.0000 - val_TN: 179759440.0000 - val_TP: 41689220.0000 - val_accuracy: 0.9386 - val_f1_m: 0.8499 - val_jaccard_score: 0.7409 - val_loss: 0.1756 - val_precision_m: 0.8494 - val_recall_m: 0.8515
# Epoch 33/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 8989371.0000 - FP: 10345019.0000 - TN: 360284544.0000 - TP: 92240408.0000 - accuracy: 0.9591 - f1_m: 0.9043 - jaccard_score: 0.8261 - loss: 0.1130 - precision_m: 0.8987 - recall_m: 0.9105
# Epoch 33: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_33.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 169s 188ms/step - FN: 8999174.0000 - FP: 10356337.0000 - TN: 360684000.0000 - TP: 92342960.0000 - accuracy: 0.9591 - f1_m: 0.9043 - jaccard_score: 0.8261 - loss: 0.1130 - precision_m: 0.8987 - recall_m: 0.9105 - val_FN: 8166454.0000 - val_FP: 6194728.0000 - val_TN: 180847920.0000 - val_TP: 40720488.0000 - val_accuracy: 0.9391 - val_f1_m: 0.8477 - val_jaccard_score: 0.7379 - val_loss: 0.1827 - val_precision_m: 0.8663 - val_recall_m: 0.8313
# Epoch 34/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 8878185.0000 - FP: 10138219.0000 - TN: 360958592.0000 - TP: 91884296.0000 - accuracy: 0.9600 - f1_m: 0.9062 - jaccard_score: 0.8292 - loss: 0.1106 - precision_m: 0.9005 - recall_m: 0.9125
# Epoch 34: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_34.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 8888250.0000 - FP: 10149657.0000 - TN: 361357408.0000 - TP: 91987104.0000 - accuracy: 0.9600 - f1_m: 0.9062 - jaccard_score: 0.8292 - loss: 0.1106 - precision_m: 0.9005 - recall_m: 0.9125 - val_FN: 6984216.0000 - val_FP: 7849283.0000 - val_TN: 179193328.0000 - val_TP: 41902720.0000 - val_accuracy: 0.9371 - val_f1_m: 0.8476 - val_jaccard_score: 0.7374 - val_loss: 0.1796 - val_precision_m: 0.8407 - val_recall_m: 0.8558
# Epoch 35/50
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 8590894.0000 - FP: 10009682.0000 - TN: 360733664.0000 - TP: 92524984.0000 - accuracy: 0.9604 - f1_m: 0.9083 - jaccard_score: 0.8327 - loss: 0.1089 - precision_m: 0.9019 - recall_m: 0.9153
# Epoch 35: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_35.keras
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 170s 189ms/step - FN: 8600686.0000 - FP: 10021000.0000 - TN: 361132992.0000 - TP: 92627672.0000 - accuracy: 0.9604 - f1_m: 0.9083 - jaccard_score: 0.8326 - loss: 0.1089 - precision_m: 0.9019 - recall_m: 0.9153 - val_FN: 7232378.0000 - val_FP: 7301901.0000 - val_TN: 179740768.0000 - val_TP: 41654580.0000 - val_accuracy: 0.9384 - val_f1_m: 0.8490 - val_jaccard_score: 0.7398 - val_loss: 0.1766 - val_precision_m: 0.8485 - val_recall_m: 0.8506
# First training phase metrics/epochs:
# {'FN': [53972704.0, 48263060.0, 43934032.0, 40195600.0, 37471072.0, 35136768.0, 33438288.0, 31810846.0, 30680488.0, 29497514.0, 28462592.0, 27446208.0, 26728280.0, 25911642.0, 25420920.0, 24483340.0, 24042920.0, 23736676.0, 23050026.0, 22543076.0, 22017406.0, 21785480.0, 21317282.0, 20803674.0, 20449176.0, 19836030.0, 19786980.0, 19507760.0, 18976898.0, 18816428.0, 18566122.0, 18282914.0, 17812910.0, 17936568.0, 17403416.0], 'FP': [73315888.0, 52904092.0, 47134272.0, 42856248.0, 39694436.0, 37530768.0, 35547072.0, 33931136.0, 32660492.0, 31233488.0, 30206042.0, 29318076.0, 28629092.0, 27704672.0, 27326594.0, 26314480.0, 26063788.0, 25578204.0, 25068606.0, 24479808.0, 24184992.0, 23778676.0, 23529962.0, 23037008.0, 22726078.0, 22432122.0, 22228072.0, 22076154.0, 21493284.0, 21404152.0, 21153292.0, 20932536.0, 20530788.0, 20431936.0, 20196080.0], 'TN': [667003968.0, 687416512.0, 693186176.0, 697464704.0, 700625536.0, 702790400.0, 704773504.0, 706388928.0, 707659840.0, 709087680.0, 710114432.0, 711002368.0, 711692096.0, 712616192.0, 712993664.0, 714005632.0, 714256640.0, 714742144.0, 715252544.0, 715840960.0, 716135168.0, 716541376.0, 716790528.0, 717283008.0, 717594496.0, 717888512.0, 718092800.0, 718244224.0, 718827008.0, 718916416.0, 719167104.0, 719387968.0, 719790208.0, 719888576.0, 720123904.0], 'TP': [148376688.0, 154086320.0, 158415376.0, 162153888.0, 164878336.0, 167212640.0, 168911088.0, 170538528.0, 171668864.0, 172851760.0, 173886720.0, 174903184.0, 175621056.0, 176437696.0, 176928560.0, 177866048.0, 178306480.0, 178612608.0, 179299440.0, 179806288.0, 180331984.0, 180563856.0, 181032304.0, 181545648.0, 181900112.0, 182513456.0, 182562480.0, 182841776.0, 183372416.0, 183532864.0, 183783328.0, 184066304.0, 184536368.0, 184412800.0, 184946128.0], 'accuracy': [0.8649701476097107, 0.892679750919342, 0.9033933877944946, 0.9118967652320862, 0.91814124584198, 0.9229134321212769, 0.9268199801445007, 0.9302597045898438, 0.9328068494796753, 0.9355751872062683, 0.9377638101577759, 0.9397831559181213, 0.9412764310836792, 0.9431229829788208, 0.9440445303916931, 0.9461132884025574, 0.9468461275100708, 0.947685718536377, 0.9489548802375793, 0.9501172304153442, 0.9509877562522888, 0.9516644477844238, 0.9524244666099548, 0.9534932971000671, 0.9541990160942078, 0.9551610350608826, 0.9554296731948853, 0.9558871984481812, 0.9570679664611816, 0.9573344588279724, 0.9578651785850525, 0.9583988785743713, 0.9593244194984436, 0.9592982530593872, 0.9601141810417175], 'f1_m': [0.6978105902671814, 0.7507017850875854, 0.7744241952896118, 0.7936401963233948, 0.8081322312355042, 0.8192505836486816, 0.8284391164779663, 0.8365039825439453, 0.8423453569412231, 0.8488131165504456, 0.8540765047073364, 0.8587809205055237, 0.8623645901679993, 0.8666946887969971, 0.86898273229599, 0.8738222718238831, 0.875596821308136, 0.8774498701095581, 0.8806470632553101, 0.8832931518554688, 0.8854458928108215, 0.8869843482971191, 0.8888998627662659, 0.8913623094558716, 0.8930437564849854, 0.8953737020492554, 0.8959948420524597, 0.8971567749977112, 0.89990234375, 0.9006128907203674, 0.9018750786781311, 0.9030234813690186, 0.9052879214286804, 0.9051538705825806, 0.9070952534675598], 'jaccard_score': [0.5405985713005066, 0.6033739447593689, 0.6341781616210938, 0.6600809097290039, 0.6800806522369385, 0.6957545280456543, 0.7090184688568115, 0.7207198739051819, 0.7293131351470947, 0.7389404773712158, 0.7468900084495544, 0.7540128827095032, 0.7594690322875977, 0.7660768628120422, 0.7696452140808105, 0.7771974205970764, 0.7799915075302124, 0.7829031944274902, 0.787890613079071, 0.7921139597892761, 0.7954896688461304, 0.7979968786239624, 0.8009867668151855, 0.8049975633621216, 0.8076800107955933, 0.8114219307899475, 0.8124632239341736, 0.8143340349197388, 0.8188106417655945, 0.8199790120124817, 0.8220621943473816, 0.8239362239837646, 0.827638566493988, 0.8274157047271729, 0.8306536674499512], 'loss': [0.3481334447860718, 0.28172817826271057, 0.25472038984298706, 0.233751356601715 ...

# %%
# --- Mine Hard Patches and Train Again ---

hard_patches = find_hard_patches(train_gen, model, threshold=0.3)
print(f"Oversampling {len(hard_patches)} hard patches...")

# Try oversampling with hard patches
if len(hard_patches) > 0:
    new_train_indices = oversample_generator(train_indices, hard_patches, multiplier=2)
else:
    print("[WARNING] No hard patches found. Using original train_indices.")
    new_train_indices = train_indices

# Final fallback: make sure train indices is not empty
if new_train_indices is None or len(new_train_indices) == 0:
    print("FATAL WARNING: new_train_indices is empty. Falling back to original train_indices.")
    new_train_indices = train_indices


#new_train_indices = oversample_generator(train_indices, hard_patches, multiplier=2)

# Final fallback: make sure train indices is not empty
if new_train_indices is None or len(new_train_indices) == 0:
    print("FATAL WARNING: new_train_indices is empty. Falling back to original train_indices.")
    new_train_indices = train_indices

train_gen_updated = PatchDataGenerator(patches_dir, indices=new_train_indices, batch_size=BATCH_SIZE)



# Log generator status
print(f"[INFO] Final train batches: {len(train_gen)} | Validation batches: {len(val_gen)}")

# Final hard stop to avoid crash
if len(train_gen) == 0:
    raise ValueError("❌ train_gen is empty. Fix your indices or data.")

csv_logger = tf.keras.callbacks.CSVLogger("training_log.csv", append=True)

# --- Second Phase Training ---
#history2 = model.fit(train_gen_updated, validation_data=val_gen, epochs=25, callbacks=callbacks, verbose=1)

history2 = model.fit(
    train_gen_updated,
    validation_data=val_gen,
    epochs=NUM_EPOC,
    callbacks=[csv_logger, tensorboard_callback, checkpoint_callback, early_stopping],
    verbose=1,
    #workers=4,
    #use_multiprocessing=True,
    #max_queue_size=10
)
print("\nSecond training phase (after hard patch mining) metrics/epochs:")
print(history2.history)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Oversampling 89 hard patches...
# [INFO] Final train batches: 899 | Validation batches: 225
# Epoch 1/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 10200058.0000 - FP: 11334816.0000 - TN: 362939424.0000 - TP: 93152176.0000 - accuracy: 0.9553 - f1_m: 0.8961 - jaccard_score: 0.8127 - loss: 0.1226 - precision_m: 0.8912 - recall_m: 0.9022
# Epoch 1: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_01.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 174s 191ms/step - FN: 10211397.0000 - FP: 11347175.0000 - TN: 363338560.0000 - TP: 93252480.0000 - accuracy: 0.9553 - f1_m: 0.8961 - jaccard_score: 0.8127 - loss: 0.1226 - precision_m: 0.8912 - recall_m: 0.9022 - val_FN: 10401934.0000 - val_FP: 4886175.0000 - val_TN: 182156464.0000 - val_TP: 38485024.0000 - val_accuracy: 0.9352 - val_f1_m: 0.8314 - val_jaccard_score: 0.7138 - val_loss: 0.1960 - val_precision_m: 0.8856 - val_recall_m: 0.7850
# Epoch 2/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9696596.0000 - FP: 10816449.0000 - TN: 363817056.0000 - TP: 93296496.0000 - accuracy: 0.9570 - f1_m: 0.9002 - jaccard_score: 0.8194 - loss: 0.1180 - precision_m: 0.8955 - recall_m: 0.9059
# Epoch 2: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_02.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 173s 190ms/step - FN: 9707431.0000 - FP: 10828532.0000 - TN: 364216064.0000 - TP: 93397696.0000 - accuracy: 0.9570 - f1_m: 0.9002 - jaccard_score: 0.8194 - loss: 0.1180 - precision_m: 0.8955 - recall_m: 0.9059 - val_FN: 7951098.0000 - val_FP: 6528889.0000 - val_TN: 180513776.0000 - val_TP: 40935848.0000 - val_accuracy: 0.9386 - val_f1_m: 0.8472 - val_jaccard_score: 0.7371 - val_loss: 0.1758 - val_precision_m: 0.8605 - val_recall_m: 0.8358
# Epoch 3/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9450696.0000 - FP: 10727971.0000 - TN: 363749152.0000 - TP: 93698704.0000 - accuracy: 0.9578 - f1_m: 0.9026 - jaccard_score: 0.8232 - loss: 0.1155 - precision_m: 0.8972 - recall_m: 0.9088
# Epoch 3: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_03.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 173s 190ms/step - FN: 9461208.0000 - FP: 10739754.0000 - TN: 364148640.0000 - TP: 93800056.0000 - accuracy: 0.9578 - f1_m: 0.9026 - jaccard_score: 0.8231 - loss: 0.1155 - precision_m: 0.8972 - recall_m: 0.9088 - val_FN: 7424205.0000 - val_FP: 6943815.0000 - val_TN: 180098848.0000 - val_TP: 41462752.0000 - val_accuracy: 0.9391 - val_f1_m: 0.8499 - val_jaccard_score: 0.7411 - val_loss: 0.1742 - val_precision_m: 0.8548 - val_recall_m: 0.8463
# Epoch 4/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - FN: 9382112.0000 - FP: 10564670.0000 - TN: 364893504.0000 - TP: 92786024.0000 - accuracy: 0.9587 - f1_m: 0.9025 - jaccard_score: 0.8230 - loss: 0.1143 - precision_m: 0.8976 - recall_m: 0.9082
# Epoch 4: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_04.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 173s 190ms/step - FN: 9392484.0000 - FP: 10576411.0000 - TN: 365291968.0000 - TP: 92888600.0000 - accuracy: 0.9587 - f1_m: 0.9025 - jaccard_score: 0.8230 - loss: 0.1143 - precision_m: 0.8976 - recall_m: 0.9082 - val_FN: 8180951.0000 - val_FP: 6155281.0000 - val_TN: 180887360.0000 - val_TP: 40706000.0000 - val_accuracy: 0.9392 - val_f1_m: 0.8480 - val_jaccard_score: 0.7382 - val_loss: 0.1789 - val_precision_m: 0.8671 - val_recall_m: 0.8308
# Epoch 5/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9018717.0000 - FP: 10280978.0000 - TN: 364712384.0000 - TP: 93614296.0000 - accuracy: 0.9598 - f1_m: 0.9064 - jaccard_score: 0.8296 - loss: 0.1110 - precision_m: 0.9010 - recall_m: 0.9126
# Epoch 5: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_05.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 174s 191ms/step - FN: 9029034.0000 - FP: 10292588.0000 - TN: 365111488.0000 - TP: 93716408.0000 - accuracy: 0.9598 - f1_m: 0.9064 - jaccard_score: 0.8296 - loss: 0.1110 - precision_m: 0.9010 - recall_m: 0.9126 - val_FN: 7307027.0000 - val_FP: 6997126.0000 - val_TN: 180045504.0000 - val_TP: 41579928.0000 - val_accuracy: 0.9394 - val_f1_m: 0.8509 - val_jaccard_score: 0.7426 - val_loss: 0.1744 - val_precision_m: 0.8542 - val_recall_m: 0.8490
# Epoch 6/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 9052342.0000 - FP: 10270163.0000 - TN: 364615776.0000 - TP: 93688152.0000 - accuracy: 0.9594 - f1_m: 0.9056 - jaccard_score: 0.8282 - loss: 0.1117 - precision_m: 0.9004 - recall_m: 0.9115
# Epoch 6: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_06.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 172s 189ms/step - FN: 9062295.0000 - FP: 10281549.0000 - TN: 365015200.0000 - TP: 93790512.0000 - accuracy: 0.9594 - f1_m: 0.9056 - jaccard_score: 0.8282 - loss: 0.1117 - precision_m: 0.9004 - recall_m: 0.9115 - val_FN: 6126978.0000 - val_FP: 8694074.0000 - val_TN: 178348608.0000 - val_TP: 42759964.0000 - val_accuracy: 0.9372 - val_f1_m: 0.8501 - val_jaccard_score: 0.7413 - val_loss: 0.1752 - val_precision_m: 0.8289 - val_recall_m: 0.8734
# Epoch 7/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8865626.0000 - FP: 10166703.0000 - TN: 365035104.0000 - TP: 93558864.0000 - accuracy: 0.9605 - f1_m: 0.9073 - jaccard_score: 0.8309 - loss: 0.1097 - precision_m: 0.9016 - recall_m: 0.9136
# Epoch 7: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_07.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 172s 189ms/step - FN: 8875473.0000 - FP: 10177989.0000 - TN: 365434304.0000 - TP: 93661680.0000 - accuracy: 0.9605 - f1_m: 0.9073 - jaccard_score: 0.8309 - loss: 0.1097 - precision_m: 0.9016 - recall_m: 0.9136 - val_FN: 8668195.0000 - val_FP: 5794251.0000 - val_TN: 181248464.0000 - val_TP: 40218748.0000 - val_accuracy: 0.9387 - val_f1_m: 0.8453 - val_jaccard_score: 0.7342 - val_loss: 0.1830 - val_precision_m: 0.8726 - val_recall_m: 0.8208
# Epoch 8/50
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - FN: 8749619.0000 - FP: 10157907.0000 - TN: 364589152.0000 - TP: 94129592.0000 - accuracy: 0.9607 - f1_m: 0.9082 - jaccard_score: 0.8324 - loss: 0.1085 - precision_m: 0.9024 - recall_m: 0.9146
# Epoch 8: saving model to /kaggle/working/008_OUTPUT/008_Keras/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/_008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_08.keras
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 172s 189ms/step - FN: 8759421.0000 - FP: 10169046.0000 - TN: 364988992.0000 - TP: 94231952.0000 - accuracy: 0.9607 - f1_m: 0.9082 - jaccard_score: 0.8324 - loss: 0.1085 - precision_m: 0.9024 - recall_m: 0.9146 - val_FN: 6533909.0000 - val_FP: 8156704.0000 - val_TN: 178885984.0000 - val_TP: 42353040.0000 - val_accuracy: 0.9377 - val_f1_m: 0.8500 - val_jaccard_score: 0.7413 - val_loss: 0.1790 - val_precision_m: 0.8370 - val_recall_m: 0.8649
#
# Second training phase (after hard patch mining) metrics/epochs:
# {'FN': [20530200.0, 19567344.0, 19027704.0, 18830596.0, 18417324.0, 18119504.0, 17835554.0, 17679352.0], 'FP': [22594044.0, 21824210.0, 21462384.0, 21260760.0, 20858032.0, 20642984.0, 20447888.0, 20305008.0], 'TN': [726551744.0, 727322112.0, 727683136.0, 727884864.0, 728287424.0, 728503040.0, 728697408.0, 728840576.0], 'TP': [184528480.0, 185491312.0, 186030960.0, 186228144.0, 186641344.0, 186939200.0, 187223072.0, 187379232.0], 'accuracy': [0.9548062682151794, 0.9566221833229065, 0.9575665593147278, 0.9579846858978271, 0.9588398337364197, 0.9593770503997803, 0.959879457950592, 0.9601930975914001], 'f1_m': [0.8941555619239807, 0.8985478281974792, 0.9007572531700134, 0.9018820524215698, 0.9038623571395874, 0.9052136540412903, 0.9064621925354004, 0.9071937799453735], 'jaccard_score': [0.8094727993011475, 0.8166111707687378, 0.8202123045921326, 0.8220454454421997, 0.8253081440925598, 0.8275359869003296, 0.829572319984436, 0.8307623267173767], 'loss': [0.12433573603630066, 0.11935708671808243, 0.11685437709093094, 0.11576460301876068, 0.11353754997253418, 0.11196433752775192, 0.11073385179042816, 0.10989372432231903], 'precision_m': [0.8896938562393188, 0.8937968015670776, 0.8957094550132751, 0.8968262672424316, 0.8986641764640808, 0.8999319672584534, 0.9009775519371033, 0.9017401337623596], 'recall_m': [0.899787962436676, 0.9042818546295166, 0.9066574573516846, 0.9077534079551697, 0.9098523259162903, 0.9112066030502319, 0.9126473069190979, 0.9132627248764038], 'val_FN': [10401934.0, 7951098.0, 7424205.0, 8180951.0, 7307027.0, 6126978.0, 8668195.0, 6533909.0], 'val_FP': [4886175.0, 6528889.0, 6943815.0, 6155281.0, 6997126.0, 8694074.0, 5794251.0, 8156704.0], 'val_TN': [182156464.0, 180513776.0, 180098848.0, 180887360.0, 180045504.0, 178348608.0, 181248464.0, 178885984.0], 'val_TP': [38485024.0, 40935848.0, 41462752.0, 40706000.0, 41579928.0, 42759964.0, 40218748.0, 42353040.0], 'val_accuracy': [0.9352003931999207, 0.9386258721351624, 0.9391003251075745, 0.9392347931861877, 0.9393713474273682, 0.93718022108078, 0.9387001991271973, 0.9377329349517822], 'val_f1_m': [0.8314165472984314, 0.8472090363502502, 0.8498600721359253, 0.8480125665664673, 0.8508906364440918, 0.8501300811767578, 0.8453336358070374, 0.8500480651855469], 'val_jaccard_score': [0.7138286828994751, 0.737110435962677, 0.7410813570022583, 0.7382404804229736, 0.7425840497016907, 0.7412542104721069, 0.7342343926429749, 0.7412616610527039], 'val_loss': [0.19604533910751343, 0.1757938712835312, 0.1742328554391861, 0.17887890338897705, 0.17438490688800812, 0.1752033531665802, 0.18300214409828186, 0.1790461540222168], 'val_precision_m': [0.8855925798416138, 0.8605058193206787, 0.8548444509506226, 0.8670793771743774, 0.8542317748069763, 0.8288534879684448, 0.8725601434707642, 0.8370003700256348], 'val_recall_m': [0.784980058670044, 0.835773766040802, 0.8463128209114075, 0.8308153748512268, 0.8489775657653809, 0.873447835445404, 0.8207657933235168, 0.8649452924728394]}

# %%
import pandas as pd
df = pd.read_csv("training_log.csv")
print(df.head())
# Out:
#    epoch          FN          FP           TN           TP  accuracy  \
# 0      0  53972704.0  73315888.0  667003968.0  148376688.0  0.864970
# 1      1  48263060.0  52904092.0  687416512.0  154086320.0  0.892680
# 2      2  43934032.0  47134272.0  693186176.0  158415376.0  0.903393
# 3      3  40195600.0  42856248.0  697464704.0  162153888.0  0.911897
# 4      4  37471072.0  39694436.0  700625536.0  164878336.0  0.918141
#
#        f1_m  jaccard_score      loss  precision_m  ...      val_FN  \
# 0  0.697811       0.540599  0.348133     0.668636  ...  11299025.0
# 1  0.750702       0.603374  0.281728     0.740962  ...  11107779.0
# 2  0.774424       0.634178  0.254720     0.767296  ...  11802935.0
# 3  0.793640       0.660081  0.233751     0.787624  ...   9990256.0
# 4  0.808132       0.680081  0.218282     0.803150  ...   9399171.0
#
#        val_FP       val_TN      val_TP  val_accuracy  val_f1_m  \
# 0  14239978.0  172802656.0  37587912.0      0.891751  0.742716
# 1  11901031.0  175141552.0  37779176.0      0.902476  0.763326
# 2   9162089.0  177880608.0  37084008.0      0.911139  0.776174
# 3   9670697.0  177372032.0  38896708.0      0.916666  0.795037
# 4   9569588.0  177473184.0  39487764.0      0.919600  0.802959
#
#    val_jaccard_score  val_loss  val_precision_m  val_recall_m
# 0           0.593405  0.282763         0.724127      0.765975
# 1           0.619693  0.259830         0.759941      0.769583
# 2           0.636784  0.241982         0.801156      0.755531
# 3           0.662261  0.224385         0.799024      0.793289
# 4           0.673284  0.216210         0.803486      0.805083
#
# [5 rows x 21 columns]

# %%
import os
# It saves locally in Colab as 'training_log.csv'
local_csv_path = 'training_log.csv'
drive_csv_path = os.path.join(tensor_log_path, f'training_log_{file_Sig}.csv')

if os.path.exists(local_csv_path):
    shutil.copy(local_csv_path, drive_csv_path)
    print(f"Copied existing CSVLogger file to: {drive_csv_path}")
# Out:
# Copied existing CSVLogger file to: /kaggle/working/008_OUTPUT/008_TensorBoard/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/log/training_log__008vggDICEOvrSmpHard_2025-08-02 15:31:04.csv

# %%
def visualize_predictions(generator, model, num_images=25, save_dir=out_path):
    os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist

    for i in range(num_images):
        X_batch, Y_batch = generator[i]
        preds = (model.predict(X_batch) > 0.5).astype("int32")

        fig, axs = plt.subplots(1, 3, figsize=(6, 2))

        axs[0].imshow(X_batch[0])
        axs[0].set_title("Original Image")

        axs[1].imshow(Y_batch[0].squeeze(), cmap='gray')
        axs[1].set_title("Ground Truth Mask")

        axs[2].imshow(preds[0].squeeze(), cmap='gray')
        axs[2].set_title("Predicted Mask")

        # Remove axes for clarity
        for ax in axs:
            ax.axis('off')

        # Save figure
        fig_path = os.path.join(save_dir, f"prediction_{file_Sig}_{i+1}.png")
        plt.savefig(fig_path, bbox_inches='tight')
        #plt.close(fig)

        # Display inline
        plt.show(fig)

        # Optional: close to free memory
        plt.close(fig)
        print(f"Saved: {fig_path}")

# Run Visualization
visualize_predictions(val_gen, model, num_images=50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_2.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_3.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_4.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_5.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_6.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_7.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_8.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_9.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_10.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_11.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_12.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_13.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_14.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_15.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_16.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_17.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_18.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_19.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_20.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_21.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_22.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_23.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_24.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_25.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_26.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_27.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_28.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_29.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_30.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_31.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_32.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_33.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_34.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_35.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_36.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_37.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_38.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_39.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_40.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_41.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_42.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_43.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_44.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_45.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_46.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_47.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_48.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_49.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Saved: /kaggle/working/008_OUTPUT/008_Output_Files/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_50.png

# %%
import shutil
import os

# Define paths
local_log_dir = "logs"  # Your existing log directory
drive_log_dir =  tensor_path  # Target in Drive

# Create destination directory if it doesn't exist
os.makedirs(drive_log_dir, exist_ok=True)

# Copy logs to Drive (preserves existing)
shutil.copytree(local_log_dir,
                os.path.join(drive_log_dir, os.path.basename(local_log_dir)),
                dirs_exist_ok=True)  # Important for appending!

print(f"Logs copied to: {drive_log_dir}")
# Out:
# Logs copied to: /kaggle/working/008_OUTPUT/008_TensorBoard/_008vggDICEOvrSmpHard_2025-08-02 15:31:04/

# %%
import os

log_path = tensor_path+"/logs"
for root, dirs, files in os.walk(log_path):
    for f in files:
        if 'tfevents' in f:
            print("Found TensorBoard file:", os.path.join(root, f))
# Out:
# Found TensorBoard file: /kaggle/working/008_OUTPUT/008_TensorBoard/_008vggDICEOvrSmpHard_2025-08-02 15:31:04//logs/fit/kan_20250802-153110/validation/events.out.tfevents.1754149376.2765566a4cfe.36.1.v2
# Found TensorBoard file: /kaggle/working/008_OUTPUT/008_TensorBoard/_008vggDICEOvrSmpHard_2025-08-02 15:31:04//logs/fit/kan_20250802-153110/validation/events.out.tfevents.1754155784.2765566a4cfe.36.3.v2
# Found TensorBoard file: /kaggle/working/008_OUTPUT/008_TensorBoard/_008vggDICEOvrSmpHard_2025-08-02 15:31:04//logs/fit/kan_20250802-153110/train/events.out.tfevents.1754155632.2765566a4cfe.36.2.v2
# Found TensorBoard file: /kaggle/working/008_OUTPUT/008_TensorBoard/_008vggDICEOvrSmpHard_2025-08-02 15:31:04//logs/fit/kan_20250802-153110/train/events.out.tfevents.1754148671.2765566a4cfe.36.0.v2

# %%
# !pip install GPUtil
# Out:
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=fc7ee10b2edebb1199d14234fc1e05e207c0ce0fd2fce12091d03e68100b21be
#   Stored in directory: /root/.cache/pip/wheels/2b/4d/8f/55fb4f7b9b591891e8d3f72977c4ec6c7763b39c19f0861595
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0

# %%
import platform
import psutil
import cpuinfo
import GPUtil
import subprocess
import pkg_resources
import socket
from datetime import datetime

def get_hardware_info():
    print("\n" + "="*40 + " Hardware Information " + "="*40)

    # System Information
    print("\n" + "-"*20 + " System Information " + "-"*20)
    print(f"System: {platform.system()}")
    print(f"Node Name: {platform.node()}")
    print(f"Release: {platform.release()}")
    print(f"Version: {platform.version()}")
    print(f"Machine: {platform.machine()}")
    print(f"Processor: {platform.processor()}")

    # CPU Information
    print("\n" + "-"*20 + " CPU Information " + "-"*20)
    cpu_info = cpuinfo.get_cpu_info()
    print(f"Processor: {cpu_info['brand_raw']}")
    print(f"Architecture: {cpu_info['arch']}")
    print(f"Bits: {cpu_info['bits']}")
    print(f"Count: {psutil.cpu_count(logical=False)} physical, {psutil.cpu_count(logical=True)} logical")
    print(f"Max Frequency: {psutil.cpu_freq().max:.2f} MHz")
    print(f"Current Frequency: {psutil.cpu_freq().current:.2f} MHz")

    # Memory Information
    print("\n" + "-"*20 + " Memory Information " + "-"*20)
    svmem = psutil.virtual_memory()
    print(f"Total RAM: {svmem.total / (1024**3):.2f} GB")
    print(f"Available RAM: {svmem.available / (1024**3):.2f} GB")
    print(f"Used RAM: {svmem.used / (1024**3):.2f} GB")
    print(f"RAM Usage: {svmem.percent}%")

    # Disk Information
    print("\n" + "-"*20 + " Disk Information " + "-"*20)
    partitions = psutil.disk_partitions()
    for partition in partitions:
        try:
            usage = psutil.disk_usage(partition.mountpoint)
            print(f"Device: {partition.device}")
            print(f"  Mountpoint: {partition.mountpoint}")
            print(f"  File System: {partition.fstype}")
            print(f"  Total Size: {usage.total / (1024**3):.2f} GB")
            print(f"  Used: {usage.used / (1024**3):.2f} GB")
            print(f"  Free: {usage.free / (1024**3):.2f} GB")
            print(f"  Usage: {usage.percent}%")
        except PermissionError:
            continue

    # GPU Information
    print("\n" + "-"*20 + " GPU Information " + "-"*20)
    try:
        gpus = GPUtil.getGPUs()
        for i, gpu in enumerate(gpus):
            print(f"GPU {i}: {gpu.name}")
            print(f"  Driver: {gpu.driver}")
            print(f"  Memory Total: {gpu.memoryTotal} MB")
            print(f"  Memory Free: {gpu.memoryFree} MB")
            print(f"  Memory Used: {gpu.memoryUsed} MB")
            print(f"  GPU Utilization: {gpu.load*100}%")
            print(f"  Temperature: {gpu.temperature} °C")
    except Exception as e:
        print(f"Could not retrieve GPU information: {e}")

def get_installed_libraries():
    print("\n" + "="*40 + " Library Information " + "="*40)

    # Get all installed packages
    installed_packages = pkg_resources.working_set

    # Common ML/DL libraries to check
    important_libraries = [
        'tensorflow', 'tensorflow-gpu', 'torch', 'torchvision', 'torchaudio',
        'numpy', 'scipy', 'pandas', 'matplotlib', 'scikit-learn',
        'keras', 'opencv-python', 'pillow', 'jupyter', 'seaborn',
        'xgboost', 'lightgbm', 'catboost', 'transformers', 'datasets',
        'flask', 'django', 'fastapi', 'requests', 'beautifulsoup4',
        'pytorch', 'cuda', 'cudnn'
    ]

    print("\n" + "-"*20 + " Key Libraries " + "-"*20)
    for lib in important_libraries:
        try:
            version = pkg_resources.get_distribution(lib).version
            print(f"{lib}: {version}")
        except:
            pass

    # Get all installed packages if needed
    # print("\n" + "-"*20 + " All Installed Packages " + "-"*20)
    # for package in sorted(installed_packages, key=lambda x: x.key):
    #     print(f"{package.key}: {package.version}")

def save_to_file(info, filename="system_info.txt"):
    with open(filename, "w") as f:
        f.write(info)
    print(f"\nInformation saved to {filename}")

def main():
    import io
    import sys

    # Redirect stdout to capture all output
    old_stdout = sys.stdout
    sys.stdout = buffer = io.StringIO()

    # Get current date and time
    print(f"System and Library Information - {sys_info}")
    print("="*100)

    # Get hardware info
    get_hardware_info()

    # Get library info
    get_installed_libraries()

    # Restore stdout
    sys.stdout = old_stdout

    # Get the captured output
    info = buffer.getvalue()

    # Print to console
    print(info)

    # Save to file
    save_to_file(info)

if __name__ == "__main__":
    main()
# Out:
# System and Library Information - 2025-08-02 15:31:04
# ====================================================================================================
#
# ======================================== Hardware Information ========================================
#
# -------------------- System Information --------------------
# System: Linux
# Node Name: 2765566a4cfe
# Release: 6.6.56+
# Version: #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# Machine: x86_64
# Processor: x86_64
#
# -------------------- CPU Information --------------------
# Processor: Intel(R) Xeon(R) CPU @ 2.00GHz
# Architecture: X86_64
# Bits: 64
# Count: 2 physical, 4 logical
# Max Frequency: 0.00 MHz
# Current Frequency: 2000.17 MHz
#
# -------------------- Memory Information --------------------
# Total RAM: 31.35 GB
# Available RAM: 26.32 GB
# Used RAM: 4.49 GB
# RAM Usage: 16.0%
#
# -------------------- Disk Information --------------------
# Device: /dev/sdb1
#   Mountpoint: /opt/bin
#   File System: ext4
#   Total Size: 121.82 GB
#   Used: 10.47 GB
#   Free: 111.33 GB
#   Usage: 8.6%
# Device: /dev/loop1
#   Mountpoint: /kaggle/lib
#   File System: ext4
#   Total Size: 19.52 GB
#   Used: 4.62 GB
#   Free: 14.88 GB
#   Usage: 23.7%
# Device: /dev/loop1
#   Mountpoint: /kaggle/input
#   File System: ext4
#   Total Size: 19.52 GB
#   Used: 4.62 GB
#   Free: 14.88 GB
#   Usage: 23.7%
# Device: /dev/loop1
#   Mountpoint: /kaggle/working
#   File System: ext4
#   Total Size: 19.52 GB
#   Used: 4.62 GB
#   Free: 14.88 GB
#   Usage: 23.7%
# Device: /dev/mapper/snap
#   Mountpoint: /etc/resolv.conf
#   File System: ext4
#   Total Size: 8062.39 GB
#   Used: 6407.50 GB
#   Free: 1654.87 GB
#   Usage: 79.5%
# Device: /dev/mapper/snap
#   Mountpoint: /etc/hostname
#   File System: ext4
#   Total Size: 8062.39 GB
#   Used: 6407.50 GB
#   Free: 1654.87 GB
#   Usage: 79.5%
# Device: /dev/mapper/snap
#   Mountpoint: /etc/hosts
#   File System: ext4
#   Total Size: 8062.39 GB
#   Used: 6407.50 GB
#   Free: 1654.87 GB
#   Usage: 79.5%
# Device: /dev/loop1
#   Mountpoint: /etc/secrets/kaggle
#   File System: ext4
#   Total Size: 19.52 GB
#   Used: 4.62 GB
#   Free: 14.88 GB
#   Usage: 23.7%
# Device: /dev/sdb1
#   Mountpoint: /usr/local/nvidia/lib64
#   File System: ext4
#   Total Size: 121.82 GB
#   Used: 10.47 GB
#   Free: 111.33 GB
#   Usage: 8.6%
# Device: /dev/sdb1
#   Mountpoint: /usr/local/cuda-12.5/targets/x86_64-linux/lib/stubs
#   File System: ext4
#   Total Size: 121.82 GB
#   Used: 10.47 GB
#   Free: 111.33 GB
#   Usage: 8.6%
#
# -------------------- GPU Information --------------------
# GPU 0: Tesla T4
#   Driver: 560.35.03
#   Memory Total: 15360.0 MB
#   Memory Free: 10869.0 MB
#   Memory Used: 4227.0 MB
#   GPU Utilization: 0.0%
#   Temperature: 72.0 °C
# GPU 1: Tesla T4
#   Driver: 560.35.03
#   Memory Total: 15360.0 MB
#   Memory Free: 14993.0 MB
#   Memory Used: 103.0 MB
#   GPU Utilization: 0.0%
#   Temperature: 54.0 °C
#
# ======================================== Library Information ========================================
#
# -------------------- Key Libraries --------------------
# tensorflow: 2.18.0
# torch: 2.6.0+cu124
# torchvision: 0.21.0+cu124
# torchaudio: 2.6.0+cu124
# numpy: 1.26.4
# scipy: 1.15.3
# pandas: 2.2.3
# matplotlib: 3.7.2
# scikit-learn: 1.2.2
# keras: 3.8.0
# opencv-python: 4.11.0.86
# pillow: 11.2.1
# seaborn: 0.12.2
# xgboost: 2.0.3
# lightgbm: 4.5.0
# catboost: 1.2.8
# transformers: 4.52.4
# datasets: 3.6.0
# flask: 3.1.1
# fastapi: 0.115.13
# requests: 2.32.4
# beautifulsoup4: 4.13.4
#
#
# Information saved to system_info.txt

# %%
import shutil

src = "/kaggle/working/system_info.txt"
dst = "/kaggle/working/008_OUTPUT/system_info.txt"

shutil.move(src, dst)
# Out:
# '/kaggle/working/008_OUTPUT/system_info.txt'

# %%
import os

root_dir = '/kaggle/working'

for root, dirs, files in os.walk(root_dir):
    level = root.replace(root_dir, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")
# Out:
# working/
#     training_log.csv
#     logs/
#         fit/
#             kan_20250802-153110/
#                 validation/
#                     events.out.tfevents.1754149376.2765566a4cfe.36.1.v2
#                     events.out.tfevents.1754155784.2765566a4cfe.36.3.v2
#                 train/
#                     events.out.tfevents.1754155632.2765566a4cfe.36.2.v2
#                     events.out.tfevents.1754148671.2765566a4cfe.36.0.v2
#     .virtual_documents/
#     008_OUTPUT/
#         system_info.txt
#         008_Output_Files/
#             _008vggDICEOvrSmpHard_2025-08-02 15:31:04/
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_14.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_37.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_39.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_49.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_1.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_21.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_34.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_44.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_40.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_6.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_10.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_2.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_35.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_8.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_30.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_45.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_29.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_38.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_48.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_26.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_31.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_42.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_36.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_19.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_13.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_7.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_9.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_17.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_12.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_23.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_4.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_15.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_41.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_11.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_22.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_46.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_47.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_50.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_43.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_5.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_18.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_28.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_3.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_25.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_32.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_33.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_24.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_20.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_16.png
#                 prediction__008vggDICEOvrSmpHard_2025-08-02 15:31:04_27.png
#                 images/
#         008_TensorBoard/
#             _008vggDICEOvrSmpHard_2025-08-02 15:31:04/
#                 logs/
#                     fit/
#                         kan_20250802-153110/
#                             validation/
#                                 events.out.tfevents.1754149376.2765566a4cfe.36.1.v2
#                                 events.out.tfevents.1754155784.2765566a4cfe.36.3.v2
#                             train/
#                                 events.out.tfevents.1754155632.2765566a4cfe.36.2.v2
#                                 events.out.tfevents.1754148671.2765566a4cfe.36.0.v2
#                 log/
#                     training_log__008vggDICEOvrSmpHard_2025-08-02 15:31:04.csv
#         008_Keras/
#             _008vggDICEOvrSmpHard_2025-08-02 15:31:04/
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_09.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_25.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_33.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_10.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_32.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_28.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_30.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_26.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_17.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_04.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_01.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_13.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_29.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_23.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_21.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_12.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_08.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_15.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_18.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_03.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_11.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_24.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_20.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_02.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_16.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_31.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_34.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_14.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_05.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_35.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_22.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_27.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_19.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_07.keras
#                 _008vggDICEOvrSmpHard_2025-08-02 15:31:04_1st_06.keras

# %%
import shutil

folder_to_zip = "/kaggle/working/008_OUTPUT"
output_zip_path = "/kaggle/working/008vggDICEOvrSmpHard"

shutil.make_archive(output_zip_path, 'zip', folder_to_zip)
# Out:
# '/kaggle/working/008vggDICEOvrSmpHard.zip'
